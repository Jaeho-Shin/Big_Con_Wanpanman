# %% [markdown]
# # Baseline_KJY

# %% [markdown]
# ## Loading Data

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
import numpy as np
from datetime import datetime
import time

import pylab as plot

# 행 많이보기
pd.set_option('display.max_row',100)
pd.set_option('display.max_columns', 100)

# 한글 폰트 설정
fm.get_fontconfig_fonts()
font_location = 'C:/Windows/Fonts/NanumGothic.ttf' # For Windows
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)
plt.rc('font', size=12)
plt.figure(figsize=(20,10))

# 지수 표현 안보기

# 데이터 로드
data = pd.read_excel('./Data/2019_data_time.xlsx', encoding='cp949', header=0, parse_dates=["방송일시"])

# 무형 제거

data.drop(data[data['상품군']=='무형'].index, inplace=True)
data.reset_index(inplace=True)



# 판매단가, 취급액 쉼표 제거 , int 변환

# data['판매단가'] = data['판매단가'].str.replace(',','').astype(int)
# data['취급액'] = data['취급액'].str.replace(',','').astype(int)
# data['노출(분)'] = data['노출(분)'].astype(int)



# 취급액 결측치 값 변경
# df.loc[df['취급액']==1]['취급액'] = 50000



# 날짜 변경 ( 다음날 데이터를 현재 날짜로 할 건지 )




# data 의 colname 영어로 변경
# index drop 필요
print(data.columns)
data.columns = ['index', 'time', 'exposure_time', 'mcode', 'product_code', 'product_name', 'category','price','salesAMT']
print(data.columns)
                
# M', 'D', 'day', 'H', 'm',
#3
# Out:
# Index(['index', '방송일시', '노출(분)', '마더코드', '상품코드', '상품명', '상품군', '판매단가', '취급액'], dtype='object')
# Index(['index', 'time', 'exposure_time', 'mcode', 'product_code',
#        'product_name', 'category', 'price', 'salesAMT'],
#       dtype='object')

# %% [markdown]
# # 전처리

# %% [markdown]
# ## time feature

# %%
data['time_month']    = data['time'].dt.month        # 월(숫자)
data['time_day']        = data['time'].dt.day          # 일(숫자)
data['time_hour']       = data['time'].dt.hour         # 시(숫자)
data['time_minute']     = data['time'].dt.minute       # 분(숫자)
data['weekofyear']    = data['time'].dt.weekofyear      # 연 기준 몇주째(숫자) (=week)
data['dayofyear']     = data['time'].dt.dayofyear       # 연 기준 몇일째(숫자)
data["day_of_the_week"] = data["time"].dt.dayofweek
data['date']        = data['time'].dt.date          # 년월일

# %%
# 홈쇼핑 하루 방송 사이클이 오전 06시(06시20분)~익일 02시(02시20분) 까지 이므로 날짜를 맞춰주는 작업 수행
# 0시~3시 사이의 방송시간을 24시~27시로 변경
# 방송 날짜와 요일을 하루전으로 변경
overnight_index_list = data.loc[(data["time_hour"] >=0) & (data["time_hour"] < 3)].index
overnight_index_list
data.loc[overnight_index_list, "time_hour"] += 24
data.loc[overnight_index_list, "time_day"] -= 1
data.loc[overnight_index_list, "dayofyear"] -= 1
data.loc[overnight_index_list, "day_of_the_week"] -= 1
data.loc[data["day_of_the_week"] == -1, "day_of_the_week"] = 6

# %%
# 다음달로 넘어가거나 다음연도로 넘어간 항목은 월,일 재조정
data.loc[(data["time_month"] == 2) & (data["time_day"] == 0), ["time_month", "time_day"]] = 1, 31
data.loc[(data["time_month"] == 3) & (data["time_day"] == 0), ["time_month", "time_day"]] = 2, 28
data.loc[(data["time_month"] == 4) & (data["time_day"] == 0), ["time_month", "time_day"]] = 3, 31
data.loc[(data["time_month"] == 5) & (data["time_day"] == 0), ["time_month", "time_day"]] = 4, 30
data.loc[(data["time_month"] == 6) & (data["time_day"] == 0), ["time_month", "time_day"]] = 5, 31
data.loc[(data["time_month"] == 7) & (data["time_day"] == 0), ["time_month", "time_day"]] = 6, 30
data.loc[(data["time_month"] == 8) & (data["time_day"] == 0), ["time_month", "time_day"]] = 7, 31
data.loc[(data["time_month"] == 9) & (data["time_day"] == 0), ["time_month", "time_day"]] = 8, 31
data.loc[(data["time_month"] == 10) & (data["time_day"] == 0), ["time_month", "time_day"]] = 9, 30
data.loc[(data["time_month"] == 11) & (data["time_day"] == 0), ["time_month", "time_day"]] = 10, 31
data.loc[(data["time_month"] == 12) & (data["time_day"] == 0), ["time_month", "time_day"]] = 11, 30
data.loc[(data["time_month"] == 1) & (data["time_day"] == 0), ["time_month", "time_day"]] = 12, 31

# %%
data[-4:]['dayofyear'] = 365
# Out:
# C:\Users\cjswo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## 기상 feature 추가 (지역별 인구수에 가중치 부여)

# %% [markdown]
# ### 데이터 불러오기

# %%
# 지역별 데이터 불러오기
seoul_df = pd.read_csv('./Data/서울.csv', encoding = 'euc-kr')
busan_df = pd.read_csv('./Data/부산.csv', encoding = 'euc-kr')
inchon_df = pd.read_csv('./Data/인천.csv', encoding = 'euc-kr')
daeseon_df = pd.read_csv('./Data/대전.csv', encoding = 'euc-kr')
daegu_df = pd.read_csv('./Data/대구.csv', encoding = 'euc-kr')
ulsan_df = pd.read_csv('./Data/울산.csv', encoding = 'euc-kr')
gwangzu_df = pd.read_csv('./Data/광주.csv', encoding = 'euc-kr')

# 지역별 인구수
seoul = 9729107
busan = 3413841
inchon = 2957026
daeseon = 1474870
daegu = 2438031
ulsan = 1148019
gwangzu = 1456468

# 지역별 인구수 합
total = seoul+busan+inchon+daeseon+ulsan+seoul+gwangzu

# 지역별 인구수 비율
seoul_rate = seoul/total
busan_rate = busan/total
inchon_rate = inchon/total
daeseon_rate = daeseon/total
daegu_rate = daegu/total
ulsan_rate = ulsan/total
gwangzu_rate = gwangzu/total

# 결측값 처리
seoul_df.fillna(0, inplace = True)
busan_df.fillna(0, inplace = True)
inchon_df.fillna(0, inplace = True)
daeseon_df.fillna(0, inplace = True)
daegu_df.fillna(0, inplace = True)
ulsan_df.fillna(0, inplace = True)
gwangzu_df.fillna(0, inplace = True)

# 비율 반영

seoul_df2 = seoul_df.drop(['일시','지점','지점명'],axis = 1)*seoul_rate
busan_df2 = busan_df.drop(['일시','지점','지점명'],axis = 1)*busan_rate 
inchon_df2 = inchon_df.drop(['일시','지점','지점명'],axis = 1)*inchon_rate
daeseon_df2 = daeseon_df.drop(['일시','지점','지점명'],axis = 1)*daeseon_rate
daegu_df2 = daegu_df.drop(['일시','지점','지점명'],axis = 1)*daegu_rate
ulsan_df2 = ulsan_df.drop(['일시','지점','지점명'],axis = 1)*ulsan_rate
gwangzu_df2 = gwangzu_df.drop(['일시','지점','지점명'],axis = 1)*gwangzu_rate

# 데이터 프레임 병합

#r_df = seoul_df2 + busan_df2 + inchon_df2 + daeseon_df2 + daegu_df2 + ulsan_df2 + gwangzu_df2 
r_df = seoul_df.drop(['일시','지점','지점명'],axis = 1)
r_df['date'] = seoul_df['일시']
r_df['date'] = pd.to_datetime(r_df['date'], format='%Y-%m-%d %H:%M:%S', errors='raise')
r_df['dayofyear'] = r_df['date'].dt.dayofyear
r_df.drop(['일 최심신적설(cm)','최대 순간 풍속(m/s)'],axis = 1 ,inplace = True)
r_df.drop(365, inplace = True)
r_df
# Out:
#      평균기온(°C)  최저기온(°C)  최고기온(°C)  강수 계속시간(hr)  1시간 최다강수량(mm)  일강수량(mm)  \
# 0        -5.0      -8.2      -0.6         0.00            0.0       0.0
# 1        -4.9      -8.8       0.2         0.00            0.0       0.0
# 2        -3.5      -8.4       3.2         0.00            0.0       0.0
# 3        -1.1      -6.2       4.1         0.00            0.0       0.0
# 4        -2.8      -5.5       1.1         0.00            0.0       0.0
# ..        ...       ...       ...          ...            ...       ...
# 360      -1.7      -4.6       2.6         0.00            0.0       0.0
# 361       1.1      -3.6       6.1         0.00            0.0       0.0
# 362       3.8       1.1       6.2         6.75            0.0       1.4
# 363       2.7      -5.7       6.8         5.08            0.0       0.4
# 364      -7.9     -10.9      -4.5         1.58            0.0       0.0
#
#      최대 풍속(m/s)  평균 풍속(m/s)  최소 상대습도(%)  평균 상대습도(%)       date  dayofyear
# 0           4.3         2.1          34        49.5 2019-01-01          1
# 1           3.6         1.7          20        42.8 2019-01-02          2
# 2           2.9         1.4          18        38.8 2019-01-03          3
# 3           3.0         1.2          34        55.5 2019-01-04          4
# 4           4.3         2.2          20        40.3 2019-01-05          5
# ..          ...         ...         ...         ...        ...        ...
# 360         4.3         2.1          23        45.4 2019-12-27        361
# 361         3.7         2.0          34        47.6 2019-12-28        362
# 362         4.4         2.9          37        52.5 2019-12-29        363
# 363         7.4         2.9          43        70.3 2019-12-30        364
# 364         7.5         3.1          26        39.3 2019-12-31        365
#
# [365 rows x 12 columns]

# %% [markdown]
# ### Reindexing

# %%
r_df.columns = ['mean_temp','min_temp','max_temp','raining_dur(hr)','rain_per_hour','rain_per_day','max_wind',
             'mean_wind','min_Humidity','mean_Humidity','date','dayofyear']

# %% [markdown]
# ### DataFrame 병합

# %%
data = pd.merge(data,r_df,on = 'dayofyear', how='left')

# %%
data
# Out:
#        index                time  exposure_time   mcode  product_code  \
# 0          0 2019-01-01 06:00:00           20.0  100346        201072
# 1          1 2019-01-01 06:00:00           20.0  100346        201079
# 2          2 2019-01-01 06:20:00           20.0  100346        201072
# 3          3 2019-01-01 06:20:00           20.0  100346        201079
# 4          4 2019-01-01 06:40:00           20.0  100346        201072
# ...      ...                 ...            ...     ...           ...
# 37367  38299 2019-12-31 23:40:00           20.0  100448        201391
# 37368  38300 2020-01-01 00:00:00           20.0  100448        201383
# 37369  38301 2020-01-01 00:00:00           20.0  100448        201390
# 37370  38302 2020-01-01 00:00:00           20.0  100448        201384
# 37371  38303 2020-01-01 00:00:00           20.0  100448        201391
#
#          product_name category   price     salesAMT  time_month  time_day  \
# 0       테이트 남성 셀린니트3종       의류   39900    2099000.0           1         1
# 1       테이트 여성 셀린니트3종       의류   39900    4371000.0           1         1
# 2       테이트 남성 셀린니트3종       의류   39900    3262000.0           1         1
# 3       테이트 여성 셀린니트3종       의류   39900    6955000.0           1         1
# 4       테이트 남성 셀린니트3종       의류   39900    6672000.0           1         1
# ...               ...      ...     ...          ...         ...       ...
# 37367   일시불쿠첸압력밥솥 6인용       주방  148000   10157000.0          12        31
# 37368  무이자쿠첸압력밥솥 10인용       주방  178000   50929000.0          12        31
# 37369  일시불쿠첸압력밥솥 10인용       주방  168000  104392000.0          12        31
# 37370   무이자쿠첸압력밥솥 6인용       주방  158000   13765000.0          12        31
# 37371   일시불쿠첸압력밥솥 6인용       주방  148000   46608000.0          12        31
#
#        time_hour  time_minute  weekofyear  dayofyear  day_of_the_week  \
# 0              6            0           1          1                1
# 1              6            0           1          1                1
# 2              6           20           1          1                1
# 3              6           20           1          1                1
# 4              6           40           1          1                1
# ...          ...          ...         ...        ...              ...
# 37367         23           40           1        365                1
# 37368         24            0           1        365                1
# 37369         24            0           1        365                1
# 37370         24            0           1        365                1
# 37371         24            0           1        365                1
#
#            date_x  mean_temp  min_temp  max_temp  raining_dur(hr)  \
# 0      2019-01-01       -5.0      -8.2      -0.6             0.00
# 1      2019-01-01       -5.0      -8.2      -0.6             0.00
# 2      2019-01-01       -5.0      -8.2      -0.6             0.00
# 3      2019-01-01       -5.0      -8.2      -0.6             0.00
# 4      2019-01-01       -5.0      -8.2      -0.6             0.00
# ...           ...        ...       ...       ...              ...
# 37367  2019-12-31       -7.9     -10.9      -4.5             1.58
# 37368  2020-01-01       -7.9     -10.9      -4.5             1.58
# 37369  2020-01-01       -7.9     -10.9      -4.5             1.58
# 37370  2020-01-01       -7.9     -10.9      -4.5             1.58
# 37371  2020-01-01       -7.9     -10.9      -4.5             1.58
#
#        rain_per_hour  rain_per_day  max_wind  mean_wind  min_Humidity  \
# 0                0.0           0.0       4.3        2.1            34
# 1                0.0           0.0       4.3        2.1            34
# 2                0.0           0.0       4.3        2.1            34
# 3                0.0           0.0       4.3        2.1            34
# 4                0.0           0.0       4.3        2.1            34
# ...              ...           ...       ...        ...           ...
# 37367            0.0           0.0       7.5        3.1            26
# 37368            0.0           0.0       7.5        3.1            26
# 37369            0.0           0.0       7.5        3.1            26
# 37370            0.0           0.0       7.5        3.1            26
# 37371            0.0           0.0       7.5        3.1            26
#
#        mean_Humidity     date_y
# 0               49.5 2019-01-01
# 1               49.5 2019-01-01
# 2               49.5 2019-01-01
# 3               49.5 2019-01-01
# 4               49.5 2019-01-01
# ...              ...        ...
# 37367           39.3 2019-12-31
# 37368           39.3 2019-12-31
# 37369           39.3 2019-12-31
# 37370           39.3 2019-12-31
# 37371           39.3 2019-12-31
#
# [37372 rows x 28 columns]

# %% [markdown]
# ## 상품군 category 별 분류

# %%
# 카테고리명 영어로 변경
data.loc[data["category"] == "의류", "category"] = "clothes"
data.loc[data["category"] == "속옷", "category"] = "underwear"
data.loc[data["category"] == "주방", "category"] = "kitchen"
data.loc[data["category"] == "농수축", "category"] = "food"
data.loc[data["category"] == "이미용", "category"] = "beauty"
data.loc[data["category"] == "가전", "category"] = "electronics"
data.loc[data["category"] == "생활용품", "category"] = "necessaries"
data.loc[data["category"] == "건강기능", "category"] = "health"
data.loc[data["category"] == "잡화", "category"] = "goods"
data.loc[data["category"] == "가구", "category"] = "furniture"
data.loc[data["category"] == "침구", "category"] = "bedding"

# %%
# 상품군 one-hot encoding
data_dummy = pd.get_dummies(data, columns=['category'], prefix='category', drop_first=True)


data_dummy = pd.get_dummies(data_dummy, columns=['time_hour'], prefix='time_hour', drop_first=True)


data_dummy = pd.get_dummies(data_dummy, columns=['time_month'], prefix='time_month', drop_first=True)


data_dummy = pd.get_dummies(data_dummy, columns=['day_of_the_week'], prefix='day_of_the_week', drop_first=True)

data_dummy.drop(columns=['index','time','product_code'],inplace=True)

# %% [markdown]
# ## Feature Correalation 확인

# %%
import seaborn as sns
from matplotlib import pyplot as plt
plt.figure(figsize=(25,25))
sns.heatmap(data_dummy.corr(), annot=True, cmap='PuBu')
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# * 상관관계 높은 유사 변수 제거 필요

# %% [markdown]
# # ML model

# %% [markdown]
# ## Define MAPE

# %%
def MAPE(y_true, y_pred): 

    return np.mean(np.abs((y_pred-y_true) / y_true)) * 100

# %% [markdown]
# ## RF

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score

# %% [markdown]
# ### Validation Data

# %%
# 이상치 제거
data_dummy = data_dummy.drop(data_dummy[data_dummy['salesAMT'] == 50000].index)

# %%
data = data.drop(data[data['salesAMT'] == 50000].index)

# %%
data_dummy.columns
# Out:
# Index(['exposure_time', 'mcode', 'product_name', 'price', 'salesAMT',
#        'time_day', 'time_minute', 'weekofyear', 'dayofyear', 'date_x',
#        'mean_temp', 'min_temp', 'max_temp', 'raining_dur(hr)', 'rain_per_hour',
#        'rain_per_day', 'max_wind', 'mean_wind', 'min_Humidity',
#        'mean_Humidity', 'date_y', 'category_bedding', 'category_clothes',
#        'category_electronics', 'category_food', 'category_furniture',
#        'category_goods', 'category_health', 'category_kitchen',
#        'category_necessaries', 'category_underwear', 'time_hour_7',
#        'time_hour_8', 'time_hour_9', 'time_hour_10', 'time_hour_11',
#        'time_hour_12', 'time_hour_13', 'time_hour_14', 'time_hour_15',
#        'time_hour_16', 'time_hour_17', 'time_hour_18', 'time_hour_19',
#        'time_hour_20', 'time_hour_21', 'time_hour_22', 'time_hour_23',
#        'time_hour_24', 'time_hour_25', 'time_hour_26', 'time_month_2',
#        'time_month_3', 'time_month_4', 'time_month_5', 'time_month_6',
#        'time_month_7', 'time_month_8', 'time_month_9', 'time_month_10',
#        'time_month_11', 'time_month_12', 'day_of_the_week_1',
#        'day_of_the_week_2', 'day_of_the_week_3', 'day_of_the_week_4',
#        'day_of_the_week_5', 'day_of_the_week_6'],
#       dtype='object')

# %%
X = data_dummy.drop(['salesAMT','product_name', 'mean_wind','mean_Humidity','date_y','date_x','rain_per_hour','mean_temp', 'max_temp'], axis = 1)

y = data_dummy['salesAMT']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 777)

# %% [markdown]
# ### Model

# %%
rfc = RandomForestRegressor(random_state = 777)


param ={
    'n_estimators'      : [100],
    'max_depth'         : [20],
    'min_samples_leaf'  : [4],
    'min_samples_split' : [2],
    'bootstrap' : [True]
}

grid_rfc = GridSearchCV(rfc, param_grid = param)

grid_rfc.fit(X_train, y_train)

print('최적 파라미터      : ', grid_rfc.best_params_)
print('최고 예측 정확도   : {0:.4f}'.format(grid_rfc.best_score_))

estimator = grid_rfc.best_estimator_

pred = estimator.predict(X_test)
print('검증 데이터 정확도 : {0:.4f}'.format(r2_score(y_test, pred)))

# %% [markdown]
# ### MAPE

# %%
MAPE(y_test, pred)

# %% [markdown]
# ### Feature importance

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

#피처 중요도 도표 그리기
featureImportance = estimator.feature_importances_
#가장 높은 중요도 기준으로 스케일링
featureImportance = featureImportance/featureImportance.max()
sorted_idx = np.argsort(featureImportance[:])
barPos = np.arange(sorted_idx[:].shape[0])+ .5
plot.barh(barPos, featureImportance[sorted_idx[:]], align='center')
plot.yticks(barPos, X_train.keys()[sorted_idx][:])
plot.xlabel('Variable Importance')
plot.show()

# %%
X_train.keys()[sorted_idx][:]

# %% [markdown]
# ## LGBM

# %% [markdown]
# ### Model

# %%
import lightgbm as lgb

model = lgb.LGBMRegressor(random_state=777, n_estimators=1000,max_depth = -1,learning_rate = 0.1,lambda_l1 = 0.1, 
                          lambda_l2 = 0.1,num_iterations = 1500)
model.fit(X_train, y_train)
predicted = model.predict(X_test)
model_score = MAPE(y_test, predicted)
# Out:
# C:\Users\cjswo\Anaconda3\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))

# %% [markdown]
# ### MAPE score

# %%
model_score
# Out:
# 51.99563284214291

# %% [markdown]
# * 유사한 상품명 취급액 추가시 60 -> 51

# %% [markdown]
# ### Feature importance

# %%
featureImportance = model.feature_importances_
#가장 높은 중요도 기준으로 스케일링
featureImportance = featureImportance/featureImportance.max()
sorted_idx = np.argsort(featureImportance[:])
barPos = np.arange(sorted_idx[:].shape[0])+ .5
plt.figure(figsize=(20,20))
plot.barh(barPos, featureImportance[sorted_idx[:]], align='center')
plot.yticks(barPos, X_train.keys()[sorted_idx][:])
plot.xlabel('Variable Importance')
plot.show()

# %% [markdown]
# # 자연어 처리

# %% [markdown]
# ## 단어 빈도수 조사

# %%
import os
import pickle
from sklearn.feature_extraction.text import CountVectorizer

# %%
sentences = list(data['product_name'])

# %%
def create_BOW(sentence,bow):
    words = sentence.split(" ")
    words = [i for i in words if i != ""]
    for word in words:
        if word == "":
            pass
        try : bow[word] += 1
        except : bow[word] = 1
    
    return bow

# %%
bow = {}
for s in sentences:
    create_BOW(s,bow)

# %%
bow_sorted = sorted(bow.items(), key=lambda x: x[1], reverse=True)
bow_sorted[:20]
# Out:
# [('일시불', 4937),
#  ('무이자', 4930),
#  ('엘지', 2837),
#  ('티비', 2231),
#  ('울트라', 1838),
#  ('에이치디', 1838),
#  ('남성', 1603),
#  ('쿠쿠전기밥솥', 1495),
#  ('여성', 1347),
#  ('3종', 1196),
#  ('쿠첸', 1174),
#  ('압력밥솥', 1168),
#  ('패키지', 1155),
#  ('침대', 1130),
#  ('LED', 1102),
#  ('6인용', 1064),
#  ('삼성', 1030),
#  ('푸마', 1010),
#  ('보루네오', 786),
#  ('유로탑', 783)]

# %%
bow_df = pd.DataFrame(bow.values(), index = bow.keys())
bow_df.sort_values(0,axis = 0, inplace = True, ascending = False)

bow_df['word freq'] = bow_df[0]

bow_df.drop(0, axis = 1, inplace = True)

bow_df['freq rate(%)'] = bow_df['word freq']*100/len(data)
print(bow_df['word freq'].sum())
bow_df.head(20)
# Out:
# 158995
#         word freq  freq rate(%)
# 일시불          4937     13.954606
# 무이자          4930     13.934820
# 엘지           2837      8.018881
# 티비           2231      6.306001
# 에이치디         1838      5.195172
# 울트라          1838      5.195172
# 남성           1603      4.530936
# 쿠쿠전기밥솥       1495      4.225671
# 여성           1347      3.807343
# 3종           1196      3.380536
# 쿠첸           1174      3.318353
# 압력밥솥         1168      3.301393
# 패키지          1155      3.264649
# 침대           1130      3.193985
# LED          1102      3.114842
# 6인용          1064      3.007434
# 삼성           1030      2.911332
# 푸마           1010      2.854801
# 보루네오          786      2.221657
# 유로탑           783      2.213177

# %% [markdown]
# * 무이자 일시불 비율 약 30% -> feature로 사용가능성 o

# %% [markdown]
# ## 무이자 일시불 취급액 차이 비교

# %%
index_m2 = []
for i in range(len(data)):
    if data['product_name'].iloc[i].split(" ")[0] == '무이자':
        index_m2.append(i)
        
index_1 = []
for i in range(len(data)):
    if data['product_name'].iloc[i].split(" ")[0] == '일시불':
        index_1.append(i)

# %%
df_m2 = data.iloc[index_m2]
df_1 = data.iloc[index_1]

# %%
print('무이자 평균 취급액 : ',df_m2['salesAMT'].mean())
print('일시불 평균 취급액 : ',df_1['salesAMT'].mean())
print('전체 평균 취급액 : ',data['salesAMT'].mean())
# Out:
# 무이자 평균 취급액 :  15337868.909276249
# 일시불 평균 취급액 :  17515800.651598454
# 전체 평균 취급액 :  23102409.22581192

# %%
df_1['salesAMT'].mean()/df_m2['salesAMT'].mean()
# Out:
# 1.1419970241762207

# %% [markdown]
# * 일시불 상품이 무이자 상품보다 약 15% 정도 평균 취급액 높음

# %%
data_dummy['halbu'] = 0
data_dummy['halbu'][index_m2] = 1

data_dummy['pay_1'] = 0
data_dummy['pay_1'][index_1] = 1
# Out:
# C:\Users\cjswo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1013         try:
# -> 1014             self._set_with_engine(key, value)
#    1015         except com.SettingWithCopyError:
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#    1053         try:
# -> 1054             self.index._engine.set_value(values, key, value)
#    1055             return
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '[45, 47, 49, 80, 82, 84, 86, 88, 90, 93, 95, 97, 99, 101, 103, 138, 140, 142, 145, 147, 149, 151, 153, 154, 228, 229, 231, 233, 237, 239, 265, 267, 269, 271, 273, 275, 312, 314, 316, 367, 369, 371, 383, 386, 388, 390, 392, 404, 406, 408, 410, 412, 414, 416, 450, 452, 454, 456, 458, 460, 500, 502, 504, 533, 535, 537, 539, 541, 543, 588, 590, 592, 651, 653, 655, 657, 659, 661, 674, 676, 677, 679, 681, 684, 686, 687, 712, 714, 716, 718, 720, 722, 728, 730, 732, 734, 736, 738, 760, 762, 764, 783, 785, 787, 796, 798, 800, 802, 804, 806, 833, 835, 837, 839, 841, 843, 851, 853, 856, 858, 860, 862, 864, 933, 935, 937, 944, 946, 948, 950, 952, 999, 1001, 1003, 1005, 1007, 1009, 1040, 1042, 1044, 1046, 1048, 1050, 1090, 1092, 1094, 1096, 1098, 1100, 1106, 1108, 1110, 1122, 1124, 1126, 1128, 1130, 1132, 1133, 1135, 1137, 1154, 1156, 1158, 1160, 1162, 1164, 1178, 1180, 1182, 1184, 1186, 1188, 1234, 1236, 1238, 1260, 1262, 1264, 1267, 1269, 1271, 1273, 1275, 1277, 1283, 1285, 1287, 1289, 1291, 1293, 1325, 1327, 1330, 1332, 1334, 1336, 1338, 1340, 1341, 1343, 1345, 1347, 1349, 1351, 1385, 1387, 1389, 1391, 1393, 1395, 1418, 1420, 1422, 1425, 1427, 1429, 1431, 1433, 1435, 1454, 1456, 1458, 1472, 1474, 1476, 1483, 1485, 1487, 1512, 1514, 1516, 1518, 1519, 1521, 1523, 1524, 1543, 1545, 1547, 1595, 1597, 1599, 1617, 1619, 1621, 1652, 1655, 1657, 1659, 1661, 1664, 1686, 1689, 1690, 1692, 1694, 1737, 1739, 1741, 1743, 1746, 1748, 1750, 1752, 1754, 1756, 1758, 1760, 1762, 1764, 1766, 1768, 1770, 1800, 1802, 1804, 1805, 1807, 1809, 1812, 1814, 1816, 1818, 1877, 1879, 1881, 1882, 1884, 1888, 1890, 1891, 1894, 1896, 1898, 1900, 1902, 1917, 1919, 1921, 1923, 1925, 1927, 1931, 1933, 1935, 1937, 1939, 1941, 1977, 1979, 1980, 1982, 1984, 1986, 1988, 1990, 2065, 2067, 2069, 2071, 2073, 2074, 2076, 2078, 2080, 2082, 2084, 2146, 2149, 2151, 2153, 2154, 2156, 2158, 2161, 2162, 2164, 2167, 2169, 2189, 2191, 2193, 2239, 2241, 2243, 2245, 2247, 2251, 2253, 2255, 2257, 2271, 2273, 2275, 2317, 2319, 2321, 2373, 2375, 2377, 2379, 2381, 2383, 2396, 2397, 2400, 2403, 2405, 2407, 2409, 2411, 2413, 2415, 2417, 2419, 2421, 2423, 2425, 2445, 2447, 2449, 2488, 2490, 2492, 2494, 2496, 2498, 2562, 2564, 2566, 2568, 2570, 2572, 2605, 2607, 2609, 2611, 2613, 2615, 2617, 2618, 2620, 2622, 2624, 2626, 2644, 2646, 2648, 2650, 2652, 2654, 2656, 2658, 2660, 2662, 2664, 2666, 2669, 2672, 2674, 2676, 2678, 2680, 2682, 2684, 2687, 2715, 2717, 2719, 2720, 2722, 2724, 2745, 2749, 2750, 2752, 2753, 2755, 2757, 2759, 2791, 2793, 2795, 2797, 2799, 2801, 2823, 2825, 2827, 2829, 2831, 2833, 2871, 2873, 2875, 2877, 2879, 2881, 2884, 2886, 2919, 2921, 2923, 2926, 2928, 2930, 2932, 2934, 2936, 2969, 2971, 2973, 2975, 2978, 2980, 2982, 2984, 2986, 2988, 2990, 2992, 3009, 3011, 3013, 3018, 3020, 3021, 3023, 3025, 3027, 3029, 3031, 3033, 3035, 3096, 3098, 3099, 3101, 3103, 3105, 3107, 3144, 3146, 3148, 3150, 3152, 3154, 3182, 3184, 3185, 3187, 3189, 3191, 3193, 3194, 3196, 3198, 3199, 3201, 3203, 3204, 3206, 3208, 3210, 3233, 3235, 3237, 3250, 3252, 3254, 3265, 3267, 3269, 3271, 3273, 3275, 3276, 3278, 3280, 3282, 3284, 3286, 3292, 3294, 3296, 3297, 3299, 3301, 3303, 3305, 3307, 3309, 3311, 3312, 3314, 3316, 3318, 3352, 3354, 3356, 3358, 3360, 3362, 3371, 3373, 3375, 3398, 3400, 3402, 3404, 3405, 3407, 3409, 3411, 3413, 3415, 3417, 3453, 3455, 3457, 3459, 3461, 3463, 3468, 3469, 3471, 3472, 3474, 3489, 3491, 3492, 3494, 3495, 3497, 3499, 3511, 3513, 3515, 3546, 3548, 3550, 3552, 3554, 3556, 3586, 3587, 3589, 3591, 3593, 3595, 3598, 3600, 3602, 3605, 3607, 3642, 3644, 3645, 3647, 3649, 3651, 3655, 3657, 3659, 3661, 3663, 3665, 3668, 3670, 3672, 3688, 3690, 3692, 3694, 3696, 3698, 3703, 3705, 3707, 3709, 3711, 3713, 3772, 3774, 3776, 3804, 3806, 3808, 3810, 3812, 3814, 3818, 3820, 3822, 3845, 3847, 3849, 3854, 3856, 3859, 3861, 3863, 3865, 3867, 3869, 3910, 3912, 3914, 3916, 3918, 3920, 3924, 3926, 3928, 3930, 3932, 3934, 3955, 3957, 3958, 3961, 3963, 3965, 3967, 3972, 3974, 3976, 4007 ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-b682b41ce735> in <module>
#       1 data_dummy['halbu'] = 0
# ----> 2 data_dummy['halbu'][index_m2] = 1
#       3
#       4 data_dummy['pay_1'] = 0
#       5 data_dummy['pay_1'][index_1] = 1
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1040                     pass
#    1041
# -> 1042             self._set_with(key, value)
#    1043
#    1044         if cacher_needs_updating:
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\core\series.py in _set_with(self, key, value)
#    1090             if key_type == "integer":
#    1091                 if self.index.inferred_type == "integer":
# -> 1092                     self._set_labels(key, value)
#    1093                 else:
#    1094                     return self._set_values(key, value)
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\core\series.py in _set_labels(self, key, value)
#    1103         mask = indexer == -1
#    1104         if mask.any():
# -> 1105             raise ValueError(f"{key[mask]} not contained in the index")
#    1106         self._set_values(indexer, value)
#    1107
#
# ValueError: [  147   153   154  1692  1737  1741  1941  2243  2321  2494  2498  2717
#   3035  3098  3099  3101  3152  3154  3352  3358  3405  3453  3455  3468
#   3469  3668  3670  4344  4346  4361  4367  4420  4467  4579  4967  5255
#   5581  5645  5877  5879  5900  6042  6094  6098  6226  6228  6230  6241
#   6436  6438  6642  6644  6744  7070  7075  7081  7458  7746  8174  8183
#   8386  8584  8656  8658  8711  8715  8801  8802  8804  8808  8915  8930
#   9042  9077  9180  9218  9219  9223  9266  9277  9283  9477  9485  9528
#   9639  9686  9688  9692  9731  9787  9802  9889 10099 10101 10107 10109
#  10116 10316 10367 10457 10499 10501 10583 10709 10833 10835 10837 10920
#  10932 11056 11057 11184 11185 11189 11585 11958 11962 12048 12050 12142
#  12146 12148 12150 12341 12345 12361 12363 12367 12558 12682 12740 12742
#  12749 12751 12752 12758 12818 12826 12848 12850 12852 12856 12858 12862
#  12864 12869 13066 13068 13074 13088 13154 13203 13322 13326 13329 13335
#  13430 13436 13444 13614 13632 13713 13717 13815 13823 13961 14079 14305
#  14334 14342 14425 14624 14626 14754 14814 14879 14881 14887 15081 15235
#  15422 15424 15803 16123 16125 16127 16398 16404 16410 16420 16854 17339
#  17343 17349 17422 17477 17513 17522 17524 19031 19035 19037 19232 19239
#  19721 19740 19742 19745 19841 20051 20447 20449 20544 20969 21009 21098
#  21118 21226 21274 21417 21659 21805 21868 22243 22244 22246 22253 22259
#  22354 22409 22411 22436 22532 22648 22692 22694 23190 23192 23212 23214
#  23423 23441 23445 23770 24017 24128 24198 24265 24267 24269 24601 24871
#  25103 26782 26788 26795 27037 27041 27413 27788 28839 29051 29053 29060
#  30218 30222 30415 31568 32167 32169 32550 32856 32858 34769 34771] not contained in the index

# %%
data_dummy.columns
# Out:
# Index(['exposure_time', 'mcode', 'product_name', 'price', 'salesAMT',
#        'time_day', 'time_minute', 'weekofyear', 'dayofyear', 'date_x',
#        'mean_temp', 'min_temp', 'max_temp', 'raining_dur(hr)', 'rain_per_hour',
#        'rain_per_day', 'max_wind', 'mean_wind', 'min_Humidity',
#        'mean_Humidity', 'date_y', 'category_bedding', 'category_clothes',
#        'category_electronics', 'category_food', 'category_furniture',
#        'category_goods', 'category_health', 'category_kitchen',
#        'category_necessaries', 'category_underwear', 'time_hour_7',
#        'time_hour_8', 'time_hour_9', 'time_hour_10', 'time_hour_11',
#        'time_hour_12', 'time_hour_13', 'time_hour_14', 'time_hour_15',
#        'time_hour_16', 'time_hour_17', 'time_hour_18', 'time_hour_19',
#        'time_hour_20', 'time_hour_21', 'time_hour_22', 'time_hour_23',
#        'time_hour_24', 'time_hour_25', 'time_hour_26', 'time_month_2',
#        'time_month_3', 'time_month_4', 'time_month_5', 'time_month_6',
#        'time_month_7', 'time_month_8', 'time_month_9', 'time_month_10',
#        'time_month_11', 'time_month_12', 'day_of_the_week_1',
#        'day_of_the_week_2', 'day_of_the_week_3', 'day_of_the_week_4',
#        'day_of_the_week_5', 'day_of_the_week_6', 'halbu'],
#       dtype='object')

# %% [markdown]
# ## 카테고리 별 최다 빈도 단어 분석

# %%
category_list = ['category_bedding', 'category_clothes', 'category_electronics',
       'category_food', 'category_furniture', 'category_goods',
       'category_health', 'category_kitchen', 'category_necessaries',
       'category_underwear']

# %%
for l in category_list:
    sentences = list(data[data_dummy[l]== 1]['product_name'])

    bow = {}
    for s in sentences:
        create_BOW(s,bow)
    
    bow_sorted = sorted(bow.items(), key=lambda x: x[1], reverse=True)
    print(l,'\n')
    
    bow_df = pd.DataFrame(bow.values(), index = bow.keys())
    bow_df.sort_values(0,axis = 0, inplace = True, ascending = False)

    bow_df['word freq'] = bow_df[0]

    bow_df.drop(0, axis = 1, inplace = True)

    bow_df['freq rate(%)'] = bow_df['word freq']*100/len(data[data_dummy[l]== 1])
    print(bow_df.head(15),'\n'*3)
# Out:
# category_bedding
#
#          word freq  freq rate(%)
# 보몽드            543     81.777108
# 침구세트           531     79.969880
# 시어서커           372     56.024096
# 리플             252     37.951807
# 샐비어            252     37.951807
# 자수             177     26.656627
# SS             123     18.524096
# Q              123     18.524096
# K              123     18.524096
# 엘사             120     18.072289
# 쿨              120     18.072289
# SK(슈퍼킹)         66      9.939759
# 토퍼침구세트          60      9.036145
# 더블착번극세사         60      9.036145
# 카밀라             60      9.036145
#
#
#
# category_clothes
#
#          word freq  freq rate(%)
# 남성            1168     26.968368
# 여성             871     20.110829
# 3종             852     19.672131
# 썸머             416      9.605172
# 뱅뱅             413      9.535904
# 4종             310      7.157700
# K-SWISS        308      7.111522
# 19             289      6.672824
# 2종             271      6.257215
# 데님팬츠           270      6.234126
# 마르엘라로사티        269      6.211037
# NNF            246      5.679982
# 헤스티지           244      5.633803
# PAT            242      5.587624
# by             242      5.587624
#
#
#
# category_electronics
#
#              word freq  freq rate(%)
# 엘지                2837     54.948673
# 무이자               2488     48.189037
# 일시불               2463     47.704823
# 티비                2231     43.211311
# 울트라               1838     35.599458
# 에이치디              1838     35.599458
# 삼성                1030     19.949642
# 엘지전자               705     13.654852
# 냉장고                661     12.802634
# 매직스페이스             612     11.853574
# 세탁기                610     11.814836
# 에어컨                607     11.756731
# 통돌이                604     11.698625
# 65UK6800HNC        538     10.420298
# 55UK6800HNC        465      9.006392
#
#
#
# category_food
#
#         word freq  freq rate(%)
# 국내산           639     16.452111
# 8팩            620     15.962925
# 20팩           324      8.341916
# 안동간고등어        318      8.187436
# 손질            276      7.106076
# x             270      6.951596
# 20kg          264      6.797116
# 멋진밥상          264      6.797116
# 흥양농협          264      6.797116
# AAB의          255      6.565396
# 소곱창전골         252      6.488157
# 800g          252      6.488157
# 유귀열의          242      6.230690
# 피시원           220      5.664264
# 귀한            218      5.612770
#
#
#
# category_furniture
#
#        word freq  freq rate(%)
# 침대          1130     49.087750
# LED         1102     47.871416
# 보루네오         786     34.144222
# 유로탑          783     34.013901
# 멀티수납형        755     32.797567
# 소파           545     23.675065
# 피올레          539     23.414422
# 천연소가죽        539     23.414422
# 루나           441     19.157255
# 서랍형          422     18.331885
# 삼익가구         422     18.331885
# 제니비          422     18.331885
# 퀸            385     16.724587
# 슈퍼싱글         343     14.900087
# 킹            337     14.639444
#
#
#
# category_goods
#
#         word freq  freq rate(%)
# 소가죽           365      9.880888
# 코치            357      9.664321
# 여성            351      9.501895
# 프라다           342      9.258257
# [루이띠에]        333      9.014618
# 남성            310      8.391987
# 삭루츠           279      7.552788
# 2종            276      7.471576
# 월드컵           272      7.363292
# 숄더백           200      5.414185
# 크로스백          200      5.414185
# 다이아몬드         198      5.360043
# 도스문도스         195      5.278831
# 18K           194      5.251760
# 토트백           192      5.197618
#
#
#
# category_health
#
#         word freq  freq rate(%)
# 종근당건강         253     32.188295
# 생유산균골드        199     25.318066
# 락토핏           199     25.318066
# 단하루           178     22.646310
# 석류            115     14.631043
# 무이자           112     14.249364
# 일시불           111     14.122137
# 루테인            93     11.832061
# 정직한            84     10.687023
# 농부의            84     10.687023
# 닥터             81     10.305344
# 뉴트리원           75      9.541985
# 다이어트           74      9.414758
# 구미             66      8.396947
# 슈퍼             57      7.251908
#
#
#
# category_kitchen
#
#           word freq  freq rate(%)
# 일시불            1946     29.614975
# 무이자            1936     29.462791
# 쿠쿠전기밥솥         1495     22.751484
# 쿠첸             1174     17.866383
# 압력밥솥           1168     17.775072
# 6인용             916     13.940040
# 10인용            761     11.581190
# 풀스텐             737     11.215949
# 대용량             533      8.111399
# 10인용(A1)        508      7.730939
# (A1)            494      7.517882
# 스텐              488      7.426571
# 가스레인지           441      6.711307
# 자동불꽃조절          441      6.711307
# 린나이             441      6.711307
#
#
#
# category_necessaries
#
#        word freq  freq rate(%)
# 일시불          396     14.301192
# 품안애          377     13.615023
# 온수매트         377     13.615023
# 무이자          373     13.470567
# 비데           277     10.003611
# 노비타          277     10.003611
# 무선           256      9.245215
# 이볼브          255      9.209101
# 시리즈          255      9.209101
# 선일금고         255      9.209101
# 2019년        196      7.078368
# 충전식          184      6.644998
# 타이거          184      6.644998
# 무료설치         178      6.428313
# 스마트          174      6.283857
#
#
#
# category_underwear
#
#        word freq  freq rate(%)
# 패키지         1072     27.416880
# 푸마          1010     25.831202
# 드로즈          775     19.820972
# 브라팬티         372      9.514066
# 트렁크          296      7.570332
# 드라이셀         296      7.570332
# 심리스          286      7.314578
# 레이스          278      7.109974
# 오모떼          266      6.803069
# 10+4종        257      6.572890
# 컬럼비아         230      5.882353
# 풍기인견         225      5.754476
# 코튼           221      5.652174
# 레이프릴         206      5.268542
# 3종           206      5.268542

# %% [markdown]
# ### 테스트셋 카테고리도 뽑아보기

# %%
test_data = pd.read_excel('./Data/test.xlsx', encoding='cp949', header=1, parse_dates=["방송일시"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-fc1ed973d44d> in <module>
# ----> 1 test_data = pd.read_excel('./Data/test.xlsx', encoding='cp949', header=1, parse_dates=["방송일시"])
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# --> 821         self._reader = self._engines[engine](self._io)
#     822
#     823     def __fspath__(self):
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# C:\Users\cjswo\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data/test.xlsx'

# %%
test_data

# %%
#무형제거
test_data.drop(test_data[test_data['상품군']=='무형'].index, inplace=True)
test_data.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-057340e9dac5> in <module>
#       1 #무형제거
# ----> 2 test_data.drop(test_data[test_data['상품군']=='무형'].index, inplace=True)
#       3 test_data.reset_index(inplace=True)
#
# NameError: name 'test_data' is not defined

# %%
test_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-8af46794cf00> in <module>
# ----> 1 test_data
#
# NameError: name 'test_data' is not defined

# %%
test_data.columns = ['index', 'time', 'exposure_time', 'mcode', 'product_code', 'product_name', 'category','price','salesAMT']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-0ebaa8829ae7> in <module>
# ----> 1 test_data.columns = ['index', 'time', 'exposure_time', 'mcode', 'product_code', 'product_name', 'category','price','salesAMT']
#
# NameError: name 'test_data' is not defined

# %%
# 카테고리명 영어로 변경
test_data.loc[test_data["category"] == "의류", "category"] = "clothes"
test_data.loc[test_data["category"] == "속옷", "category"] = "underwear"
test_data.loc[test_data["category"] == "주방", "category"] = "kitchen"
test_data.loc[test_data["category"] == "농수축", "category"] = "food"
test_data.loc[test_data["category"] == "이미용", "category"] = "beauty"
test_data.loc[test_data["category"] == "가전", "category"] = "electronics"
test_data.loc[test_data["category"] == "생활용품", "category"] = "necessaries"
test_data.loc[test_data["category"] == "건강기능", "category"] = "health"
test_data.loc[test_data["category"] == "잡화", "category"] = "goods"
test_data.loc[test_data["category"] == "가구", "category"] = "furniture"
test_data.loc[test_data["category"] == "침구", "category"] = "bedding"

# 상품군 one-hot encoding
test_data_dummy = pd.get_dummies(test_data, columns=['category'], prefix='category', drop_first=True)
test_data_dummy.drop(columns=['index','time','product_name','product_code'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-2821f0e1ea70> in <module>
#       1 # 카테고리명 영어로 변경
# ----> 2 test_data.loc[test_data["category"] == "의류", "category"] = "clothes"
#       3 test_data.loc[test_data["category"] == "속옷", "category"] = "underwear"
#       4 test_data.loc[test_data["category"] == "주방", "category"] = "kitchen"
#       5 test_data.loc[test_data["category"] == "농수축", "category"] = "food"
#
# NameError: name 'test_data' is not defined

# %%
# test set 카테고리별 단어추출
for l in category_list:
    sentences = list(test_data[test_data_dummy[l]== 1]['product_name'])

    bow = {}
    for s in sentences:
        create_BOW(s,bow)
    
    bow_sorted = sorted(bow.items(), key=lambda x: x[1], reverse=True)
    print('test_set ',l,'\n')
    
    bow_df = pd.DataFrame(bow.values(), index = bow.keys())
    bow_df.sort_values(0,axis = 0, inplace = True, ascending = False)

    bow_df['word freq'] = bow_df[0]

    bow_df.drop(0, axis = 1, inplace = True)

    bow_df['freq rate(%)'] = bow_df['word freq']*100/len(test_data[test_data_dummy[l]== 1])
    print(bow_df.head(40),'\n'*3)
    
    
    # train set 6월
    sentences = list(data[data_dummy[l]== 1]['product_name'])

    bow = {}
    for s in sentences:
        create_BOW(s,bow)
    
    bow_sorted = sorted(bow.items(), key=lambda x: x[1], reverse=True)
    print('train_set ',l,'\n')
    
    bow_df = pd.DataFrame(bow.values(), index = bow.keys())
    bow_df.sort_values(0,axis = 0, inplace = True, ascending = False)

    bow_df['word freq'] = bow_df[0]

    bow_df.drop(0, axis = 1, inplace = True)

    bow_df['freq rate(%)'] = bow_df['word freq']*100/len(data[data_dummy[l]== 1])
    print(bow_df.head(40),'\n'*3)
    

        
    # train set 6월
    sentences = list(data[data['time_month'] == 6][data_dummy[l] == 1]['product_name'])

    bow = {}
    for s in sentences:
        create_BOW(s,bow)
    
    bow_sorted = sorted(bow.items(), key=lambda x: x[1], reverse=True)
    print('train_set 6월 ',l,'\n')
    
    bow_df = pd.DataFrame(bow.values(), index = bow.keys())
    bow_df.sort_values(0,axis = 0, inplace = True, ascending = False)

    bow_df['word freq'] = bow_df[0]

    bow_df.drop(0, axis = 1, inplace = True)

    bow_df['freq rate(%)'] = bow_df['word freq']*100/len(data[data['time_month'] == 6][data_dummy[l] == 1]['product_name'])
    print(bow_df.head(40),'\n'*3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-2f51db8784b7> in <module>
#       1 # test set 카테고리별 단어추출
#       2 for l in category_list:
# ----> 3     sentences = list(test_data[test_data_dummy[l]== 1]['product_name'])
#       4
#       5     bow = {}
#
# NameError: name 'test_data' is not defined

# %% [markdown]
# ## Word2Vec

# %%
from konlpy.tag import Twitter

def twitter_tokenizer(x):
    return twitter.morphs(x)

twitter = Twitter()
# Out:
# C:\Users\cjswo\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
data['token'] = data['product_name'].apply(twitter_tokenizer)
# total 변수에 대한 Tokenizing

# %%
my_list = data['token'].tolist()
sentences = []
for v in my_list:
    if v not in sentences:
        sentences.append(v)

len(sentences)
# 이중 리스트로 구성 -> gensim input이 이중 리스트임.
# Out:
# 1674

# %%
from gensim.models import Word2Vec, FastText
# input format : [["my", "name", "is", "jamie"], ["jamie", "is", "cute"]]
# size : 임베딩 차원
# window : 윈도우 사이즈
# min_count : 고려할 단어의 최소 빈도 기준
# workers : cpu core 수
# iter : 반복 학습 횟수(epoch)
# sg : 0 -> CBOW, 1 -> Skip-Gram
# CBOW_model - Word2Vec(corpus, size=2, window=2, min_count=2, workers=1, iter=1000, sg=1)

# %%
Skip_Gram_model = Word2Vec(sentences, size=100, window=2, min_count=10, workers=8, iter=1000, sg=1)

# %%
words = Skip_Gram_model.wv.index2word
words[:100]

# %%
vectors = Skip_Gram_model.wv.vectors

# %% [markdown]
# ## Doc2Vec

# %%
product_names = pd.Series(data=sentences, index = (range(len(sentences))))

# %%
product_names_df = pd.DataFrame(product_names, columns=['token'])
product_names_df
# Out:
#                                                   token
# 0                             [테이, 트, 남성, 셀린, 니트, 3, 종]
# 1                             [테이, 트, 여성, 셀린, 니트, 3, 종]
# 2                             [오, 모, 떼, 레이스, 파운데이션, 브라]
# 3             [CERINI, by, PAT, 남성, 소프트, 기모, 릴, 렉스, 팬츠]
# 4                                   [보코, 리버시, 블, 무스, 탕]
# ...                                                 ...
# 1669                            [조방, 할매, 낙곱새, 6, 팩, 세트]
# 1670  [파격, 가, 니, 봇, 무선, 진공, 물걸레, 로봇청소기, +, 뉴, 헤어드라이어...
# 1671                                [램프, 쿡, 자동, 회전, 냄비]
# 1672                  [벨라, 홈, 스마트, 멀티, 포트, 1, +, 1, 세트]
# 1673                               [코몽트, 기모, 터틀넥, 5, 종]
#
# [1674 rows x 1 columns]

# %%
from soynlp.tokenizer import RegexTokenizer, LTokenizer, MaxScoreTokenizer
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
product_names_df["index"] = [str(i) for i in np.arange(len(product_names_df))]

# %%
from collections import namedtuple
TaggedDocument = namedtuple('TaggedDocument', 'words tags')
tagged_train_docs = [TaggedDocument(d,c) for d, c in product_names_df[['token', 'index']].values]
print(len(tagged_train_docs))
# Out:
# 1674

# %%
import multiprocessing
cores = multiprocessing.cpu_count()
cores
# Out:
# 8

# %%
doc_vectorizer = Doc2Vec(
    dm=0,            # PV-DBOW / default 1
    dbow_words=1,    # w2v simultaneous with DBOW d2v / default 0
    window=8,        # distance between the predicted word and context words
    size=50,        # vector size
    alpha=0.025,     # learning-rate
    seed=1234,
    min_count=2,    # ignore with freq lower
    min_alpha=0.025, # min learning-rate
    workers=cores)   # multi cpu
    #hs = 1,          # hierarchical softmax / default 0
    #negative = 10,   # negative sampling / default 5)
# Out:
# C:\Users\cjswo\Anaconda3\lib\site-packages\gensim\models\doc2vec.py:319: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
tagged_train_docs
# Out:
# [TaggedDocument(words=['테이', '트', '남성', '셀린', '니트', '3', '종'], tags='0'),
#  TaggedDocument(words=['테이', '트', '여성', '셀린', '니트', '3', '종'], tags='1'),
#  TaggedDocument(words=['오', '모', '떼', '레이스', '파운데이션', '브라'], tags='2'),
#  TaggedDocument(words=['CERINI', 'by', 'PAT', '남성', '소프트', '기모', '릴', '렉스', '팬츠'], tags='3'),
#  TaggedDocument(words=['보코', '리버시', '블', '무스', '탕'], tags='4'),
#  TaggedDocument(words=['CERINI', 'by', 'PAT', '남성', '풀', '패키지', '기', '모', '니트', '3', '종'], tags='5'),
#  TaggedDocument(words=['크로커다일', 'The', '편안한', '코튼', '브라', '팬티', '4', '세트'], tags='6'),
#  TaggedDocument(words=['에코', '라', '믹', '통', '주물', '스톤', '냄비', '세트'], tags='7'),
#  TaggedDocument(words=['오', '모', '떼', '360', '도', '텐션', '업', '레이스', '패키지', '시즌', '4'], tags='8'),
#  TaggedDocument(words=['그렉', '노먼', '남성', '구', '스', '다운', '롱', '벤치', '코트'], tags='9'),
#  TaggedDocument(words=['그렉', '노먼', '여성', '구', '스', '다운', '롱', '벤치', '코트'], tags='10'),
#  TaggedDocument(words=['뽕', '셰프', '이봉원', '특', '갈비탕', '12', '팩'], tags='11'),
#  TaggedDocument(words=['국내', '산', '손질', '갑오징어', '8', '팩'], tags='12'),
#  TaggedDocument(words=['멋진', '밥상', '흥양', '농협', '햅쌀', '20', 'kg'], tags='13'),
#  TaggedDocument(words=['비버리힐스', '폴로', '클럽', '남성', '기초', '세트', '(', '2018', 'FW', '골드', ')'], tags='14'),
#  TaggedDocument(words=['우리', '바다', '손질', '왕', '꼬막', '24', '팩'], tags='15'),
#  TaggedDocument(words=['푸마', '에어', '핏', '서', '포트', '브라', '세트', '15', '종', '+', '4', '종'], tags='16'),
#  TaggedDocument(words=['일', '시불', '엘지', '통', '돌이', '세탁기'], tags='17'),
#  TaggedDocument(words=['무', '이자', '엘지', '통', '돌이', '세탁기'], tags='18'),
#  TaggedDocument(words=['마리', '노블', '밍크', '롱', '코트'], tags='19'),
#  TaggedDocument(words=['헤스', '티', '지', '엘레나', '라쿤', '양', '가죽', '콤비', '롱', '코트'], tags='20'),
#  TaggedDocument(words=['로베르', '타', '디', '까', '메리노', '올', '레이스', '지퍼', '브라', '팬티'], tags='21'),
#  TaggedDocument(words=['그렉', '노먼', '남성', '캐시', '터치', '터틀넥', '4', '종'], tags='22'),
#  TaggedDocument(words=['그렉', '노먼', '여성', '캐시', '터치', '터틀넥', '4', '종'], tags='23'),
#  TaggedDocument(words=['레이', '프릴', '무빙', '맥시', '풀', '커버', '브라', '팬티'], tags='24'),
#  TaggedDocument(words=['벨라', '홈', '논', '슬립', '옷', '걸이', '세트'], tags='25'),
#  TaggedDocument(words=['(', '직', '매입', ')', '종근당', '건강', '아이', '클리어', '루테', '인'], tags='26'),
#  TaggedDocument(words=['NNF', '쿠션', '퍼', '자켓', '+', '베스트'], tags='27'),
#  TaggedDocument(words=['일', '시불', '쿠첸', '풀스텐', '압력밥솥', '10', '인용', '(', 'A', '1', ')'], tags='28'),
#  TaggedDocument(words=['무', '이자', '쿠첸', '풀스텐', '압력밥솥', '10', '인용', '(', 'A', '1', ')'], tags='29'),
#  TaggedDocument(words=['일', '시불', '쿠첸', '풀스텐', '압력밥솥', '6', '인용', '(', 'A', '1', ')'], tags='30'),
#  TaggedDocument(words=['무', '이자', '쿠첸', '풀스텐', '압력밥솥', '6', '인용', '(', 'A', '1', ')'], tags='31'),
#  TaggedDocument(words=['무', '이자', '린', '나이', '간편', '쿡', '자동', '불꽃', '조절', '가스레인지', '3', '구'], tags='32'),
#  TaggedDocument(words=['일', '시불', '린', '나이', '간편', '쿡', '자동', '불꽃', '조절', '가스레인지', '3', '구'], tags='33'),
#  TaggedDocument(words=['무', '이자', '린', '나이', '간편', '쿡', '자동', '불꽃', '조절', '가스레인지', '2', '구'], tags='34'),
#  TaggedDocument(words=['일', '시불', '린', '나이', '간편', '쿡', '자동', '불꽃', '조절', '가스레인지', '2', '구'], tags='35'),
#  TaggedDocument(words=['하늘', '내린', '용', '대리', '황태', '10', '미'], tags='36'),
#  TaggedDocument(words=['안동', '간', '고등어', '20', '팩'], tags='37'),
#  TaggedDocument(words=['SPC', '삼립', '한', '입', '호빵', '13', '봉', '(', '혼합', ',', '팥', '8', '+', '야채', '5', '봉', ')'], tags='38'),
#  TaggedDocument(words=['SPC', '삼립', '한', '입', '호빵', '13', '봉', '(', '단일', ',', '팥', '13', '봉', ')'], tags='39'),
#  TaggedDocument(words=['바다', '먹자', '국내', '산', '손질', '꽃게', '7', '팩'], tags='40'),
#  TaggedDocument(words=['키친', '플라워', '대', '용량', '디지털', '에어', '프라이어', '5', 'L'], tags='41'),
#  TaggedDocument(words=['피시', '원', '국내', '산', '손질', '대구', '8', '팩', '*', '매운탕', '양념', '8', '팩'], tags='42'),
#  TaggedDocument(words=['푸마', '코튼', '라이크라', '드로즈', '12', '종'], tags='43'),
#  TaggedDocument(words=['푸마', 'INNO', '심', '리스', '롱', '드로즈', '7', '종'], tags='44'),
#  TaggedDocument(words=['푸마', '드라이', '셀라', '인', '뉴', '런닝', '9', '종'], tags='45'),
#  TaggedDocument(words=['일', '시불', '엘지', '전자', '매직', '스페이스', '냉장고'], tags='46'),
#  TaggedDocument(words=['무', '이자', '엘지', '전자', '매직', '스페이스', '냉장고'], tags='47'),
#  TaggedDocument(words=['일', '시불', '엘지', '울트라', '에이치', '디', '티비', '55', 'UK', '6800', 'HNC'], tags='48'),
#  TaggedDocument(words=['일', '시불', '엘지', '울트라', '에이치', '디', '티비', '65', 'UK', '6800', 'HNC'], tags='49'),
#  TaggedDocument(words=['무', '이자', '엘지', '울트라', '에이치', '디', '티비', '65', 'UK', '6800', 'HNC'], tags='50'),
#  TaggedDocument(words=['무', '이자', '엘지', '울트라', '에이치', '디', '티비', '55', 'UK', '6800', 'HNC'], tags='51'),
#  TaggedDocument(words=['무', '이자', '엘지', '울트라', '에이치', '디', '티비', '70', 'UK', '7400', 'KNA'], tags='52'),
#  TaggedDocument(words=['크로커다일', '풀', '커버', '레이스', '브라', '팬티', '4', '세트'], tags='53'),
#  TaggedDocument(words=['푸마', '웜셀', '기모', '치마', '레깅스', '3', '종'], tags='54'),
#  TaggedDocument(words=['에펨', '여성', '미', '들퍼', '부츠'], tags='55'),
#  TaggedDocument(words=['에펨', '남성', '미', '들퍼', '부츠'], tags='56'),
#  TaggedDocument(words=['천연', '담아', '명품', '다시', '팩', '100', '포'], tags='57'),
#  TaggedDocument(words=['엘렌', '실라', '달팽이', '크림', '(', '콜라겐', '5', '+', '팩트', '3', ')'], tags='58'),
#  TaggedDocument(words=['로베르', '타', '디', '까', '메리노', '노벨라', '백', '2', '종'], tags='59'),
#  TaggedDocument(words=['한일', '대', '용량', '스텐', '분쇄', '믹서기'], tags='60'),
#  TaggedDocument(words=['(', '도', '냄', ')', '무', '이자', '쿠쿠', '전기밥솥', '10', '인용'], tags='61'),
#  TaggedDocument(words=['(', '도', '냄', ')', '일', '시불', '쿠쿠', '전기밥솥', '10', '인용'], tags='62'),
#  TaggedDocument(words=['(', '도', '냄', ')', '무', '이자', '쿠쿠', '전기밥솥', '6', '인용'], tags='63'),
#  TaggedDocument(words=['(', '도', '냄', ')', '일', '시불', '쿠쿠', '전기밥솥', '6', '인용'], tags='64'),
#  TaggedDocument(words=['청정', '수산', '완도', '활', '전복', '35', '미'], tags='65'),
#  TaggedDocument(words=['영산포', '숙성', '홍어', '8', '팩', '+', '무침', '3', '통'], tags='66'),
#  TaggedDocument(words=['푸마', 'INNO', '심', '리스', '드로즈', '(', '6', '차', ')'], tags='67'),
#  TaggedDocument(words=['푸마', 'INNO', '심', '리스', '롱', '드로즈', '(', '1', '차', ')'], tags='68'),
#  TaggedDocument(words=['푸마', 'NEW', '트렁크', '패키지'], tags='69'),
#  TaggedDocument(words=['노비타', '스마트', '비데'], tags='70'),
#  TaggedDocument(words=['일', '시불', '엘지', '울트라', '에이치', '디', '티비', '70', 'UK', '7400', 'KNA'], tags='71'),
#  TaggedDocument(words=['제주', '농장', '유기', '양배추', '진액', '120', '포'], tags='72'),
#  TaggedDocument(words=['코', '이모', '리', '빙박스', '8', '종'], tags='73'),
#  TaggedDocument(words=['로베르', '타', '디', '까', '메리노', '360', '커브', '드', '지퍼', '쉐이핑', '란쥬'], tags='74'),
#  TaggedDocument(words=['소', '들', '녘', '소', '갈비탕'], tags='75'),
#  TaggedDocument(words=['스포', '메', '틱', '스', '리얼', '핏', '모', '이스', '춰라', '이징', '코코넛', '크림'], tags='76'),
#  TaggedDocument(words=['일', '시불', '[', '가이거', ']', '제니스', '시계', '주얼리', '세트'], tags='77'),
#  TaggedDocument(words=['무', '이자', '[', '가이거', ']', '제니스', '시계', '주얼리', '세트'], tags='78'),
#  TaggedDocument(words=['스칼프', '솔루션', '트리트먼트', '패키지'], tags='79'),
#  TaggedDocument(words=['아문센', '남성', '윈터', '하드', '쉘', '세트'], tags='80'),
#  TaggedDocument(words=['아문센', '여성', '윈터', '하드', '쉘', '세트'], tags='81'),
#  TaggedDocument(words=['마담', '팰리스', '웜', '기모', '롱', '베스트', '3', '종', '세트'], tags='82'),
#  TaggedDocument(words=['오', '모', '떼', '프런트', '후크', '데', '오브', '라', '시즌', '2'], tags='83'),
#  TaggedDocument(words=['K', '-', 'SWISS', '남성', '기', '모', '티셔츠', '5', '종'], tags='84'),
#  TaggedDocument(words=['K', '-', 'SWISS', '여', '성', '기', '모', '티셔츠', '5', '종'], tags='85'),
#  TaggedDocument(words=['(', 'a', '4', ')', '팽현숙', '의', '순대', '곱창', '전골', '&', '볶음'], tags='86'),
#  TaggedDocument(words=['종근당', '건강', '전립', '쎈', '프라임'], tags='87'),
#  TaggedDocument(words=['마리', '끌', '레르', '파리', '컬렉션', '리얼', '하', '이드', '로', '립스틱', '(', '리뉴얼', ')'], tags='88'),
#  TaggedDocument(words=['아', '리스', '토우', '남성', '기', '모', '티셔츠', '5', '종'], tags='89'),
#  TaggedDocument(words=['스위스', '밀리터리', '전', '동', '공', '구', '세트'], tags='90'),
#  TaggedDocument(words=['도', '네', '이', '남성', '터틀넥', '스웨터', '4', '종'], tags='91'),
#  TaggedDocument(words=['도', '네', '이', '여성', '터틀넥', '스웨터', '4', '종'], tags='92'),
#  TaggedDocument(words=['레이', '프릴', '더블', '엑스', '매직', '니', '퍼', '팬티', '(', 'FW', '리뉴얼', ')'], tags='93'),
#  TaggedDocument(words=['쿠', '미투', '니', '카', '하이', '서', '포트', '심', '리스', '란쥬', '&', '팬티'], tags='94'),
#  TaggedDocument(words=['에코', '라', '믹', '컬링', '스톤', '프라이팬', '세트'], tags='95'),
#  TaggedDocument(words=['농협', '안심', '벌꿀', '4', '병'], tags='96'),
#  TaggedDocument(words=['일', '시불', '메디', '쉴드', '자동', '목', '견인', '기기'], tags='97'),
#  TaggedDocument(words=['무', '이자', '메디', '쉴드', '자동', '목', '견인', '기기'], tags='98'),
#  TaggedDocument(words=['소', '들', '녘', '더', '맛있는', 'NEW', '돼지', '왕', '구이', '12', '팩'], tags='99'),
#  TaggedDocument(words=['에버', '라스트', '남성', '기능', '성', '에어로', '웜', '동', '내의', '3', '세트'], tags='100'),
#  TaggedDocument(words=['에버', '라스트', '여성', '기능', '성', '에어로', '웜', '동', '내의', '3', '세트'], tags='101'),
#  TaggedDocument(words=['테이', '트', '남성', '기', '모', '티셔츠', '6', '종'], tags='102'),
#  TaggedDocument(words=['테이', '트', '여성', '기', '모', '티셔츠', '6', '종'], tags='103'),
#  TaggedDocument(words=['보코', '폭스', '퍼구스', '다운', '롱패딩'], tags='104'),
#  TaggedDocument(words=['더블유', '베일', '풀', '스킨', '폭스', '카라', '머스크', '랫', '코트'], tags='105'),
#  TaggedDocument(words=['천', '수', '봉명', '인', '선재', '전통', '메주', '세트'], tags='106'),
#  TaggedDocument(words=['카파', '드로즈', '패키지', '12', '종'], tags='107'),
#  TaggedDocument(words=['카파', '런닝', '패키지', '9', '종'], tags='108'),
#  TaggedDocument(words=['로이', '몬스터', '남녀', '벤치', '후드', '롱패딩'], tags='109'),
#  TaggedDocument(words=['일', '시불', '삼성', '노트북', '9', '메탈', '고급', '형', 'NT', '900', 'X', '5', 'J', '-', 'K', '28'], tags='110'),
#  TaggedDocument(words=['무', '이자', '삼성', '노트북', '9', '메탈', '고급', '형', 'NT', '900', 'X', '5', 'J', '-', 'K', '28'], tags='111'),
#  TaggedDocument(words=['일', '시불', '삼성', '노트북', '9', '메탈', '기본', '형', 'NT', '900', 'X', '5', 'J', '-', 'K', '14'], tags='112'),
#  TaggedDocument(words=['무', '이자', '삼성', '노트북', '9', '메탈', '기본', '형', 'NT', '900', 'X', '5', 'J', '-', 'K', '14'], tags='113'),
#  TaggedDocument(words=['아', '리스', '토우', '남성', '패딩', '트랙', '수트', '세트'], tags='114'),
#  TaggedDocument(words=['아', '리스', '토우', '여성', '패딩', '트랙', '수트', '세트'], tags='115'),
#  TaggedDocument(words=['쿠', '미투', '니', '카', '황후', '의', '코르셋', '하이', '웨', '이스트', '팬티', '(', '리뉴얼', ')'], tags='116'),
#  TaggedDocument(words=['임', '페리', '얼', '남성', '릴', '렉스', '본', '딩', '팬츠', '3', '종'], tags='117'),
#  TaggedDocument(words=['임', '페리', '얼', '여성', '릴', '렉스', '본', '딩', '팬츠', '3', '종'], tags='118'),
#  TaggedDocument(words=['카파', '발란스', '테크', '브라', '팬티', '12', '세트'], tags='119'),
#  TaggedDocument(words=['일', '시불', '[', '가이거', ']', '콘체르토', '다이아몬드', '워치', '(', '주얼리', '3', '종', ')'], tags='120'),
#  TaggedDocument(words=['무', '이자', '[', '가이거', ']', '콘체르토', '다이아몬드', '워치', '(', '주얼리', '3', '종', ')'], tags='121'),
#  TaggedDocument(words=['로베르', '타', '디', '까', '메리노', '트리플', '커버', '지퍼', '쉐이핑', '란쥬'], tags='122'),
#  TaggedDocument(words=['무', '이자', '스위스', '밀리터리', '에어', '프라이어'], tags='123'),
#  TaggedDocument(words=['일', '시불', '스위스', '밀리터리', '에어', '프라이어'], tags='124'),
#  TaggedDocument(words=['무', '이자', '모', '즈', '커피', '머신', '&', '미니', '오븐'], tags='125'),
#  TaggedDocument(words=['일', '시불', '모', '즈', '커피', '머신', '&', '미니', '오븐'], tags='126'),
#  TaggedDocument(words=['무', '이자', '모', '즈', '커피', '머신'], tags='127'),
#  TaggedDocument(words=['일', '시불', '모', '즈', '커피', '머신'], tags='128'),
#  TaggedDocument(words=['무', '이자', '모', '즈', '미니', '오븐'], tags='129'),
#  TaggedDocument(words=['일', '시불', '모', '즈', '미니', '오븐'], tags='130'),
#  TaggedDocument(words=['제주', '한라봉', '2', '박스', '+', '천혜향', '1', '박스'], tags='131'),
#  TaggedDocument(words=['베지밀', '검은', '콩', '두유', '96', '팩'], tags='132'),
#  TaggedDocument(words=['무', '이자', '아이오', '진', '공포', '장기'], tags='133'),
#  TaggedDocument(words=['일', '시불', '아이오', '진', '공포', '장기'], tags='134'),
#  TaggedDocument(words=['궁', '중', '손질', '새우', '200', '미', '+', '동태', '포', '200', 'g'], tags='135'),
#  TaggedDocument(words=['이봉원', '정직한', '안', '창살', '+', '갈비살', '구이'], tags='136'),
#  TaggedDocument(words=['세인트', '스', '코트', '얼티밋', '캐리어', '7', '종', '세트', '(', '백', '팩', ')'], tags='137'),
#  TaggedDocument(words=['일', '시불', '락앤락', '블랙', '우드', '칼', '블럭', '7', '종', '+', '키친', '툴', '7', '종'], tags='138'),
#  TaggedDocument(words=['무', '이자', '락앤락', '블랙', '우드', '칼', '블럭', '7', '종', '+', '키친', '툴', '7', '종'], tags='139'),
#  TaggedDocument(words=['키친', '플라워', '참', '소쿠리', '2', '세트'], tags='140'),
#  TaggedDocument(words=['키친', '플라워', '참', '소쿠리', '1', '세트'], tags='141'),
#  TaggedDocument(words=['도스', '문', '도스', '카이만', '엠보', '소', '가죽', '핸드백', '1', '종'], tags='142'),
#  TaggedDocument(words=['보코', '퀼팅', '베스트', '+', '터틀넥', '2', '종'], tags='143'),
#  TaggedDocument(words=['락앤락', '비', '스프', '리', '온', '더', '테이블', '밀폐', '용기', '세트'], tags='144'),
#  TaggedDocument(words=['에버', '홈', '직화', '그릴'], tags='145'),
#  TaggedDocument(words=['일', '시불', '삼성', '유', '에이치', '디', '티비', 'UN', '55', 'NU', '7010', 'FXKR'], tags='146'),
#  TaggedDocument(words=['무', '이자', '삼성', '유', '에이치', '디', '티비', 'UN', '55', 'NU', '7010', 'FXKR'], tags='147'),
#  TaggedDocument(words=['일', '시불', '삼성', '유', '에이치', '디', '티비', 'UN', '65', 'NU', '7010', 'FXKR'], tags='148'),
#  TaggedDocument(words=['무', '이자', '삼성', '유', '에이치', '디', '티비', 'UN', '65', 'NU', '7010', 'FXKR'], tags='149'),
#  TaggedDocument(words=['무', '이자', '삼성', '유', '에이치', '디', '티비', 'UN', '75', 'NU', '7010', 'FXKR'], tags='150'),
#  TaggedDocument(words=['몬테', '밀라노', '어메이징', '핏', '하이', '웨스트', '팬티', '10', '종'], tags='151'),
#  TaggedDocument(words=['일', '시불', '한삼', '인', '순', '홍', '삼진', '7', '박스', '(', '백', 'A', '1', ')'], tags='152'),
#  TaggedDocument(words=['무', '이자', '한삼', '인', '순', '홍', '삼진', '7', '박스', '(', '백', 'A', '1', ')'], tags='153'),
#  TaggedDocument(words=['메시', '제이', '퀼팅', '코트', '+', '퍼', '베스트'], tags='154'),
#  TaggedDocument(words=['오', '모', '떼', '리얼', '스킨', '쉐이핑', '브라', '팬티'], tags='155'),
#  TaggedDocument(words=['씨', '엔', '지', '코리아', '방역', '용', '마스크', 'KF', '94', '60', '매'], tags='156'),
#  TaggedDocument(words=['[', '농협', ']', '대학', '찰', '옥수수', '10', '봉', '(', '30', '개', ')'], tags='157'),
#  TaggedDocument(words=['전철', '우', '소', '갈비살', '구이', '10', '팩'], tags='158'),
#  TaggedDocument(words=['[', '수협', ']', '자연', '산', '제주', '옥돔', '+', '갈치', '세트'], tags='159'),
#  TaggedDocument(words=['올리고', '가스', '와이드', '그릴', '레인지', '프리미엄', '형'], tags='160'),
#  TaggedDocument(words=['올리고', '가스', '와이드', '그릴', '레인지', '기본', '형'], tags='161'),
#  TaggedDocument(words=['임', '페리', '얼', '남성', '울', '블렌딩', '니트', '3', '종'], tags='162'),
#  TaggedDocument(words=['임', '페리', '얼', '여성', '울', '블렌딩', '니트', '3', '종'], tags='163'),
#  TaggedDocument(words=['보코', '윈터', '기모', '풀코디', '4', '종', '세트'], tags='164'),
#  TaggedDocument(words=['AAE', 'LA', '갈비', '7', '팩'], tags='165'),
#  TaggedDocument(words=['컬럼비아', '옴', '니', '위', '크', '드로즈', '패키지', '10', '종'], tags='166'),
#  TaggedDocument(words=['컬럼비아', '옴', '니', '히트', '롱', '드로즈', '패키지', '7', '종'], tags='167'),
#  TaggedDocument(words=['컬럼비아', '옴', '니', '위', '크', '머슬', '언더셔츠', '6', '종'], tags='168'),
#  TaggedDocument(words=['일', '시불', '삼성', '유', '에이치', '디', '티비', 'UN', '75', 'NU', '7010', 'FXKR'], tags='169'),
#  TaggedDocument(words=['남영', '비비안', '스킨', '핏', 'Dream', 'Fit', '브라', '팬티'], tags='170'),
#  TaggedDocument(words=['헤스', '떼벨', '웜', '업', '란쥬쉐이퍼'], tags='171'),
#  TaggedDocument(words=['일', '시불', '삼성', '블루', '스카이', '공기청정기', 'AX', '40', 'N', '3080', 'DMD', '1', '세트'], tags='172'),
#  TaggedDocument(words=['무', '이자', '삼성', '블루', '스카이', '공기청정기', 'AX', '40', 'N', '3080', 'DMD', '1', '세트'], tags='173'),
#  TaggedDocument(words=['일', '시불', '삼성', '블루', '스카이', '공기청정기', 'AX', '40', 'N', '3080', 'DMD', '2', '세트'], tags='174'),
#  TaggedDocument(words=['무', '이자', '삼성', '블루', '스카이', '공기청정기', 'AX', '40', 'N', '3080', 'DMD', '2', '세트'], tags='175'),
#  TaggedDocument(words=['NNF', '여성', '롱패딩', '1', '종'], tags='176'),
#  TaggedDocument(words=['일', '시불', '삼성', '건조기', '9', 'kg', '블랙', '케', '비어', 'DV', '90', 'M', '53', 'B', '0', 'QV'], tags='177'),
#  TaggedDocument(words=['무', '이자', '삼성', '건조기', '9', 'kg', '블랙', '케', '비어', 'DV', '90', 'M', '53', 'B', '0', 'QV'], tags='178'),
#  TaggedDocument(words=['일', '시불', '삼성', '건조기', '9', 'kg', '화이트', 'DV', '90', 'M', '53', 'B', '0', 'QW'], tags='179'),
#  TaggedDocument(words=['무', '이자', '삼성', '건조기', '9', 'kg', '화이트', 'DV', '90', 'M', '53', 'B', '0', 'QW'], tags='180'),
#  TaggedDocument(words=['일', '시불', '삼성', '건조기', '9', 'kg', '이', '녹스', '실버', 'DV', '90', 'M', '53', 'B', '0', 'QP'], tags='181'),
#  TaggedDocument(words=['무', '이자', '삼성', '건조기', '9', 'kg', '이', '녹스', '실버', 'DV', '90', 'M', '53', 'B', '0', 'QP'], tags='182'),
#  TaggedDocument(words=['제주', '바다', '7분', '손질', '문어'], tags='183'),
#  TaggedDocument(words=['크리스티나', '앤코', '기', '모', '티셔츠', '세트'], tags='184'),
#  TaggedDocument(words=['옛날', '그', '쥐포', '110', '장', '(', '11', '팩', ')'], tags='185'),
#  TaggedDocument(words=['일', '시불', '대우전자', '미니', '건조기', 'DWR', '-', '03', 'IDDC'], tags='186'),
#  TaggedDocument(words=['무', '이자', '대우전자', '미니', '건조기', 'DWR', '-', '03', 'IDDC'], tags='187'),
#  TaggedDocument(words=['무', '이자', '대우전자', '미니', '건조기', 'DWR', '-', '03', 'IDWH'], tags='188'),
#  TaggedDocument(words=['일', '시불', '대우전자', '미니', '건조기', 'DWR', '-', '03', 'IDWH'], tags='189'),
#  TaggedDocument(words=['레이', '프릴', '무빙', '맥시', '풀', '커버', '브라', '팬티', '(', '리뉴얼', ')'], tags='190'),
#  TaggedDocument(words=['일', '시불', '쿠첸', '스마트', '투', '인원', '티', '메이커'], tags='191'),
#  TaggedDocument(words=['무', '이자', '쿠첸', '스마트', '투', '인원', '티', '메이커'], tags='192'),
#  TaggedDocument(words=['보코', '니트웨어', '풀코디'], tags='193'),
#  TaggedDocument(words=['마', '스케', '라', '밍크', '니', '팅', '모자', '세트'], tags='194'),
#  TaggedDocument(words=['마', '스케', '라', '풀', '스킨', '밍크', '머플러', '세트'], tags='195'),
#  TaggedDocument(words=['해피', '콜', 'IH', '진공', '스텐', '냄비', '에디', '션'], tags='196'),
#  TaggedDocument(words=['구워', '만든', '곡물', '그대로', '21', ',', '3', '종', '20', '봉'], tags='197'),
#  TaggedDocument(words=['구워', '만든', '곡물', '그대로', '21', ',', '오', '리지', '널', '10', '봉'], tags='198'),
#  TaggedDocument(words=['크', '린', '조', '이', '황사', '방역', '마스크', '대형', '105', '매'], tags='199'),
#  TaggedDocument(words=['크', '린', '조', '이', '황사', '방역', '마스크', '소형', '105', '매'], tags='200'),
#  TaggedDocument(words=['국내', '생산', '스텐락', '심플', '스텐', '밀폐', '용기', '17', '종'], tags='201'),
#  TaggedDocument(words=['더블유', '베일', '캐시', '라', '이크', '니트', '4', '종'], tags='202'),
#  TaggedDocument(words=['쓰임', '마호가니', '원목', '도마', '4', '종', '세트'], tags='203'),
#  TaggedDocument(words=['로벤', '탈', '국내', '산', 'IH', '실버', '팬', '세트'], tags='204'),
#  TaggedDocument(words=['청정', '수산', '완도', '활', '전복', '中', '사이즈', '26', '미'], tags='205'),
#  TaggedDocument(words=['장보고', '완도', '매', '생', '이', '30', '개'], tags='206'),
#  TaggedDocument(words=['뉴', '클레', '린', '티', '메이커', '시', '그', '니', '처', '플러스', '1', '+', '1'], tags='207'),
#  TaggedDocument(words=['뉴', '클레', '린', '티', '메이커', '플러스'], tags='208'),
#  TaggedDocument(words=['CERINI', 'by', 'PAT', '남성', '집업', '니트', '4', '종'], tags='209'),
#  TaggedDocument(words=['일', '시불', '엘지', '울트라', '에이치', '디', '티비', '70', 'UK', '6800', 'HNC'], tags='210'),
#  TaggedDocument(words=['무', '이자', '엘지', '울트라', '에이치', '디', '티비', '70', 'UK', '6800', 'HNC'], tags='211'),
#  TaggedDocument(words=['오', '모', '떼', '에어', '홀릭', '브라', '팬티'], tags='212'),
#  TaggedDocument(words=['엘르', '메르', '시', '(', 'Merci', ')', '토트', '백', '세트'], tags='213'),
#  TaggedDocument(words=['무', '이자', '쿠쿠', '전기밥솥', '10', '인용'], tags='214'),
#  TaggedDocument(words=['일', '시불', '쿠쿠', '전기밥솥', '10', '인용'], tags='215'),
#  TaggedDocument(words=['무', '이자', '쿠쿠', '전기밥솥', '6', '인용'], tags='216'),
#  TaggedDocument(words=['일', '시불', '쿠쿠', '전기밥솥', '6', '인용'], tags='217'),
#  TaggedDocument(words=['무', '이자', '린', '나이', '자동', '불꽃', '조절', '가스레인지', '3', '구'], tags='218'),
#  TaggedDocument(words=['무', '이자', '린', '나이', '자동', '불꽃', '조절', '가스레인지', '2', '구'], tags='219'),
#  TaggedDocument(words=['일', '시불', '린', '나이', '자동', '불꽃', '조절', '가스레인지', '2', '구'], tags='220'),
#  TaggedDocument(words=['일', '시불', '린', '나이', '자동', '불꽃', '조절', '가스레인지', '3', '구'], tags='221'),
#  TaggedDocument(words=['세균', '싹', '행주', '티슈'], tags='222'),
#  TaggedDocument(words=['해피', '콜', 'X', '2', '싱크', '릴', '분리', '가능', '양면', '그릴'], tags='223'),
#  TaggedDocument(words=['일', '시불', '삼성', '유로', '피안', '냉장고', 'RS', '82', 'M', '6000', 'S', '8'], tags='224'),
#  TaggedDocument(words=['무', '이자', '삼성', '유로', '피안', '냉장고', 'RS', '82', 'M', '6000', 'S', '8'], tags='225'),
#  TaggedDocument(words=['보루', '네오', '루나', '유로', '탑', '멀티', '수납', '형', 'LED', '침대', 'SS', '슈퍼', '싱글'], tags='226'),
#  TaggedDocument(words=['보루', '네오', '루나', '유로', '탑', '멀티', '수납', '형', 'LED', '침대', 'Q', '퀸'], tags='227'),
#  TaggedDocument(words=['보루', '네오', '루나', '유로', '탑', '멀티', '수납', '형', 'LED', '침대', 'K', '킹'], tags='228'),
#  TaggedDocument(words=['레이', '프릴', '골드', '라벨', '무빙', '란쥬'], tags='229'),
#  TaggedDocument(words=['아키', '조끼', '형', '더블', '보정', '란쥬', '쉐이퍼', '(', '96', '차', ')'], tags='230'),
#  TaggedDocument(words=['K', '-', 'SWISS', '남성', '약', '기', '모', '팬츠', '3', '종'], tags='231'),
#  TaggedDocument(words=['종근당', '건강', '프로', '메', '가', '오메가', '3', '파워'], tags='232'),
#  TaggedDocument(words=['일', '시불', '엘지', '노트북', '그램', '15', '인치', '15', 'Z', '980', '-', 'L', '.', 'AR', '1', 'DK'], tags='233'),
#  TaggedDocument(words=['일', '시불', '엘지', '노트북', '그램', '15', '인치', '15', 'Z', '980', '-', 'G', '.', 'AR', '3', 'DK'], tags='234'),
#  TaggedDocument(words=['무', '이자', '엘지', '노트북', '그램', '15', '인치', '15', 'Z', '980', '-', 'L', '.', 'AR', '1', 'DK'], tags='235'),
#  TaggedDocument(words=['무', '이자', '엘지', '노트북', '그램', '15', '인치', '15', 'Z', '980', '-', 'G', '.', 'AR', '3', 'DK'], tags='236'),
#  TaggedDocument(words=['특집', '이롬', '황', '성주', '1일', '1', '생식', '스페셜'], tags='237'),
#  TaggedDocument(words=['아이', '넥스', '프리미엄', '올스텐', '싱크', '선반'], tags='238'),
#  TaggedDocument(words=['일', '시불', '락앤락', '유로', '오븐', '글라스', '세트'], tags='239'),
#  TaggedDocument(words=['무', '이자', '락앤락', '유로', '오븐', '글라스', '세트'], tags='240'),
#  TaggedDocument(words=['통째', '로', '착즙', '한', '루비', '석류', '즙', '84', '포'], tags='241'),
#  TaggedDocument(words=['자연', '산', '손질', '통오징어', '21', '미'], tags='242'),
#  TaggedDocument(words=['일', '시불', '삼성', '유', '에이치', '디', '국민', '티비', 'UN', '55', 'NU', '7010', 'FXKR'], tags='243'),
#  TaggedDocument(words=['무', '이자', '삼성', '유', '에이치', '디', '국민', '티비', 'UN', '55', 'NU', '7010', 'FXKR'], tags='244'),
#  TaggedDocument(words=['파시노', '이', '지', '앤퀵', '빗살', '뿌리', '펌'], tags='245'),
#  TaggedDocument(words=['월드컵', '남성', '워킹', '화', '+', '슬립', '온'], tags='246'),
#  TaggedDocument(words=['월드컵', '여성', '워킹', '화', '+', '슬립', '온'], tags='247'),
#  TaggedDocument(words=['가', ')', '세', '렌', '셉템버', '다이아', '체크', '리', '빙박스', '+', '압축', '팩'], tags='248'),
#  TaggedDocument(words=['무', '이자', '쿠쿠', '하이브리드', '인덕션레인지', '(', '프리미엄', '형', ')'], tags='249'),
#  TaggedDocument(words=['일', '시불', '쿠쿠', '하이브리드', '인덕션레인지', '(', '프리미엄', '형', ')'], tags='250'),
#  TaggedDocument(words=['무', '이자', '쿠쿠', '하이브리드', '인덕션레인지', '(', '고급', '형', ')'], tags='251'),
#  TaggedDocument(words=['일', '시불', '쿠쿠', '하이브리드', '인덕션레인지', '(', '고급', '형', ')'], tags='252'),
#  TaggedDocument(words=['루', '이바', '셋', '여성', '기모', '웜', '본', '딩', '팬츠', '3', '종'], tags='253'),
#  TaggedDocument(words=['마리', '노블', '밍크', '퍼', '베스트'], tags='254'),
#  TaggedDocument(words=['달바', '화이트', '트러플', '퍼스트', '인텐', '시브', '세', '럼'], tags='255'),
#  TaggedDocument(words=['천연', '담아', '명품', '다시', '팩', '120', '포'], tags='256'),
#  TaggedDocument(words=['(', '일', ')', '삼익', '가구', 'LED', '제', '니', '비', '서랍', '형', '침대', 'SS'], tags='257'),
#  TaggedDocument(words=['(', '무', ')', '삼익', '가구', 'LED', '제', '니', '비', '서랍', '형', '침대', 'SS'], tags='258'),
#  TaggedDocument(words=['(', '일', ')', '삼익', '가구', 'LED', '제', '니', '비', '서랍', '형', '침대', 'Q'], tags='259'),
#  TaggedDocument(words=['(', '일', ')', '삼익', '가구', 'LED', '제', '니', '비', '서랍', '형', '침대', 'K'], tags='260'),
#  TaggedDocument(words=['(', '무', ')', '삼익', '가구', 'LED', '제', '니', '비', '서랍', '형', '침대', 'K'], tags='261'),
#  TaggedDocument(words=['(', '무', ')', '삼익', '가구', 'LED', '제', '니', '비', '서랍', '형', '침대', 'Q'], tags='262'),
#  TaggedDocument(words=['강원도', '양구', '간편', '시래기', '+', '시래기', '들깨', '무침'], tags='263'),
#  TaggedDocument(words=['NNF', '더블', '페이스', '쿠션', '재킷', '+', '베스트'], tags='264'),
#  TaggedDocument(words=['푸마', '심', '리스', '드로즈', '블랙', '에디', '션', '패키지'], tags='265'),
#  TaggedDocument(words=['푸마', '트렁크', '블랙', '에디', '션', '패키지'], tags='266'),
#  TaggedDocument(words=['몬테', '밀라노', '컴', '포트', '앤핏', '브라', '팬티', '5', '+', '5', '세트'], tags='267'),
#  TaggedDocument(words=['까사', '마루', '행거', '2', '단'], tags='268'),
#  TaggedDocument(words=['멋진', '밥상', '흥양', '농협', '쌀', '20', 'kg'], tags='269'),
#  TaggedDocument(words=['칼리', '베이직', '여성', '백', '3', '종', '세트'], tags='270'),
#  TaggedDocument(words=['벨라', '홈', '릴', '렉스', '체어'], tags='271'),
#  TaggedDocument(words=['무', '이자', '프로', '피쿡', '에어', '프라이어'], tags='272'),
#  TaggedDocument(words=['일', '시불', '프로', '피쿡', '에어', '프라이어'], tags='273'),
#  TaggedDocument(words=['키친', '아트', '스텐', '밀폐', '용기', '세트'], tags='274'),
#  TaggedDocument(words=['바로바로', '무선', '청소기'], tags='275'),
#  TaggedDocument(words=['벨라', '홈', '논', '슬립', '옷', '걸이', '세트', '1', '+', '1'], tags='276'),
#  TaggedDocument(words=['올바로', '바른', '자세', '밴드', '2', '종', '세트'], tags='277'),
#  TaggedDocument(words=['캘리포니아', '카라', '카라', '오렌지', '8', 'kg'], tags='278'),
#  TaggedDocument(words=['푸마', '드라이', '셀', '퓨징', '브라', '세트', '패키지'], tags='279'),
#  TaggedDocument(words=['푸마', '드라이', '셀', '쉐이핑', '레깅스', '3', '종'], tags='280'),
#  TaggedDocument(words=['푸마', '드라이', '셀', '치마', '레깅스', '3', '종'], tags='281'),
#  TaggedDocument(words=['아가', '타', '여성', '주얼', '슬립', '온', '+', '스트랩', '슬립', '온'], tags='282'),
#  TaggedDocument(words=['오', '모', '떼', '미라클', '쉐이핑', '브라', '팬티', '시즌', '2'], tags='283'),
#  TaggedDocument(words=['쿠', '미투', '니', '카', '퍼펙트', '클린', '레이스', '브라', '팬티'], tags='284'),
#  TaggedDocument(words=['일', '시불', '선일금고', '이볼브', '시리즈', 'EV', '-', '040'], tags='285'),
#  TaggedDocument(words=['무', '이자', '선일금고', '이볼브', '시리즈', 'EV', '-', '040'], tags='286'),
#  TaggedDocument(words=['일', '시불', '선일금고', '이볼브', '시리즈', 'EV', '-', '020'], tags='287'),
#  TaggedDocument(words=['무', '이자', '선일금고', '이볼브', '시리즈', 'EV', '-', '020'], tags='288'),
#  TaggedDocument(words=['로베르', '타', '디', '까', '메리노', '아쿠아', '마레', '백', '팩', '4', '종', '세트'], tags='289'),
#  TaggedDocument(words=['무', '이자', '아이', '넥스', '프리미엄', '올스텐', '싱크', '선반'], tags='290'),
#  TaggedDocument(words=['일', '시불', '아이', '넥스', '프리미엄', '올스텐', '싱크', '선반'], tags='291'),
#  TaggedDocument(words=['닥터', '슈퍼', '루테', '인'], tags='292'),
#  TaggedDocument(words=['일', '시불', '쿠첸', '풀스텐', '압력밥솥', '10', '인용'], tags='293'),
#  TaggedDocument(words=['(', '일', ')', '한', '샘', 'HG', '화이트', '실버', '슬림', '붙박', '이장', '(', '3.2', 'm', ')'], tags='294'),
#  TaggedDocument(words=['(', '무', ')', '한', '샘', 'HG', '화이트', '실버', '슬림', '붙박', '이장', '(', '3.2', 'm', ')'], tags='295'),
#  TaggedDocument(words=['(', '일', ')', '한', '샘', 'HG', '화이트', '실버', '슬림', '붙박', '이장', '(', '4.2', 'm', ')'], tags='296'),
#  TaggedDocument(words=['(', '무', ')', '한', '샘', 'HG', '화이트', '실버', '슬림', '붙박', '이장', '(', '4.2', 'm', ')'], tags='297'),
#  TaggedDocument(words=['(', '일', ')', '한', '샘', 'HG', '화이트', '실버', '슬림', '붙박', '이장', '(', '2.2', 'm', ')'], tags='298'),
#  TaggedDocument(words=['(', '무', ')', '한', '샘', 'HG', '화이트', '실버', '슬림', '붙박', '이장', '(', '2.2', 'm', ')'], tags='299'),
#  TaggedDocument(words=['크리스티나', '앤코', '가디건', '세트'], tags='300'),
#  TaggedDocument(words=['보코', '기모', '퀼팅', '패딩'], tags='301'),
#  TaggedDocument(words=['김정문', '의', '섬진강', '재첩국', '11', '팩', '3.3', 'kg'], tags='302'),
#  TaggedDocument(words=['그렉', '노먼', '남성', '봄', '컬렉션', '티셔츠', '5', '종'], tags='303'),
#  TaggedDocument(words=['그렉', '노먼', '여성', '봄', '컬렉션', '티셔츠', '5', '종'], tags='304'),
#  TaggedDocument(words=['에르', '나벨', '체크', '배색', '데', '일리', '트렌치코트'], tags='305'),
#  TaggedDocument(words=['헤스', '티', '지', '그레이스', '양', '가죽', '코트'], tags='306'),
#  TaggedDocument(words=['헤스', '티', '지', '마론', '양', '가죽', '남성', '집업', '재킷'], tags='307'),
#  TaggedDocument(words=['무', '이자', '김병만', '의', '달인', '공구', '세트'], tags='308'),
#  TaggedDocument(words=['일', '시불', '김병만', '의', '달인', '공구', '세트'], tags='309'),
#  TaggedDocument(words=['그렉', '노먼', '남성', '디보', '티', '컬렉션', '트렌치코트', '1', '종'], tags='310'),
#  TaggedDocument(words=['그렉', '노먼', '여성', '디보', '티', '컬렉션', '트렌치코트', '1', '종'], tags='311'),
#  TaggedDocument(words=['청정', '수산', '완도', '활', '전복', '大', '사이즈', '20', '미'], tags='312'),
#  TaggedDocument(words=['국내', '산', '손질', '갑오징어', '9', '팩'], tags='313'),
#  TaggedDocument(words=['국내', '산', '특', '大', '손질', '갑오징어', '6', '팩'], tags='314'),
#  TaggedDocument(words=['보코', '여성', '울', '코트', '1', '종'], tags='315'),
#  TaggedDocument(words=['푸마', '드로즈', '블랙', '에디', '션', '패키지'], tags='316'),
#  TaggedDocument(words=['NNF', '소프트', '베스트', '앙상블'], tags='317'),
#  TaggedDocument(words=['코튼', '데이', '유기농', '순면', '마스크', 'KF', '94', '60', '매'], tags='318'),
#  TaggedDocument(words=['여자', '를', '위', '한', '빨강', '팥물', ',', '레드', '빈', '티톡', '100', '포'], tags='319'),
#  TaggedDocument(words=['여자', '를', '위', '한', '빨강', '팥물', ',', '레드', '빈', '티톡', '50', '포'], tags='320'),
#  TaggedDocument(words=['무', '이자', '쿠', '진나', '이프', '케어', '살균', '건조기', '풀', '세트'], tags='321'),
#  TaggedDocument(words=['일', '시불', '쿠', '진나', '이프', '케어', '살균', '건조기', '풀', '세트'], tags='322'),
#  TaggedDocument(words=['엔셀라두스', '밴딩', '팬츠', '3', '종'], tags='323'),
#  TaggedDocument(words=['월드컵', '남성', '다이얼', '트레킹', '화', '세트'], tags='324'),
#  TaggedDocument(words=['월드컵', '여', '성', '다이얼', '트레킹', '화', '세트'], tags='325'),
#  TaggedDocument(words=['무', '이자', '에지', '리', '스텐', '큐브', '프라이팬'], tags='326'),
#  TaggedDocument(words=['일', '시불', '에지', '리', '스텐', '큐브', '프라이팬'], tags='327'),
#  TaggedDocument(words=['베스트', '하임', '에어', '프라이어'], tags='328'),
#  TaggedDocument(words=['아키', '풀', '커버', '라이크라', '레이스', '패키지', '(', '106', '차', ')'], tags='329'),
#  TaggedDocument(words=['NNF', 'SS', '트레이닝', '세트'], tags='330'),
#  TaggedDocument(words=['노', '와', '스텐', '대', '용량', '에어', '프라이어', '4', 'L'], tags='331'),
#  TaggedDocument(words=['CERINI', 'by', 'PAT', '남성', '스프링', '릴', '렉스', '팬츠', '3', '종'], tags='332'),
#  TaggedDocument(words=['헤비', '추얼', '여성', '이', '지', '라이프', '데님', '팬츠', '3', '종'], tags='333'),
#  TaggedDocument(words=['헤비', '추얼', '남성', '이', '지', '라이프', '데님', '팬츠', '3', '종'], tags='334'),
#  TaggedDocument(words=['뱅뱅', '남성', '봄', '데님', '팬츠', '3', '종'], tags='335'),
#  TaggedDocument(words=['뱅뱅', '여성', '봄', '데님', '팬츠', '3', '종'], tags='336'),
#  TaggedDocument(words=['(', '일', ')', '3', '인용', '한', '샘', '뉴', '퍼스', '티', '지', 'R', '리', '클라이너'], tags='337'),
#  TaggedDocument(words=['(', '일', ')', '4', '인용', '한', '샘', '뉴', '퍼스', '티', '지', 'R', '리', '클라이너'], tags='338'),
#  TaggedDocument(words=['(', '무', ')', '4', '인용', '한', '샘', '뉴', '퍼스', '티', '지', 'R', '리', '클라이너'], tags='339'),
#  TaggedDocument(words=['(', 'ARS', '10%', ')', '크로커다일', '풀', '커버', '레이스', '브라', '팬티', '4', '세트'], tags='340'),
#  TaggedDocument(words=['테이', '트', '여성', 'SS', '트렌', '치', '재킷'], tags='341'),
#  TaggedDocument(words=['테이', '트', '남성', 'SS', '트렌', '치', '재킷'], tags='342'),
#  TaggedDocument(words=['에펨', '남성', 'NEW', '컴', '포트', '캐', '쥬얼', '슈즈'], tags='343'),
#  TaggedDocument(words=['에펨', '여성', 'NEW', '컴', '포트', '캐', '쥬얼', '슈즈'], tags='344'),
#  TaggedDocument(words=['남영', '비비안', '소', '노르', '베르사유', '노', '와이어', '컬렉션', '브라'], tags='345'),
#  TaggedDocument(words=['일', '시불', '엘지', '퓨리', '케어', '공기청정기', 'AS', '281', 'DAW'], tags='346'),
#  TaggedDocument(words=['무', '이자', '엘지', '퓨리', '케어', '공기청정기', 'AS', '281', 'DAW'], tags='347'),
#  TaggedDocument(words=['일', '시불', '엘지', '퓨리', '케어', '공기청정기', 'AS', '181', 'DAW'], tags='348'),
#  TaggedDocument(words=['무', '이자', '엘지', '퓨리', '케어', '공기청정기', 'AS', '181', 'DAW'], tags='349'),
#  TaggedDocument(words=['엘지', '생활', '건강', '테크', '한장', '빨래', '화이트', '업', '(', '30', '매', 'X', '9', '박스', ')'], tags='350'),
#  TaggedDocument(words=['굿', '프렌드', '굿', '터치', '클리', '너', '1', '+', '1'], tags='351'),
#  TaggedDocument(words=['굿', '프렌드', '굿', '터치', '클리', '너'], tags='352'),
#  TaggedDocument(words=['우리', '바다', '손질', '왕', '꼬막', '20', '팩'], tags='353'),
#  TaggedDocument(words=['헤비', '추얼', '여성', '트렌치', '맥', '코트'], tags='354'),
#  TaggedDocument(words=['헤비', '추얼', '남성', '트렌치', '맥', '코트'], tags='355'),
#  TaggedDocument(words=['2019', 'S', '/', 'S', '엘리자베스', '아덴', '선글라스', '2', '종'], tags='356'),
#  TaggedDocument(words=['삭루츠', '크로스', '바디', '백', '(', 'TQ', '12', ')'], tags='357'),
#  TaggedDocument(words=['삭루츠', '버켓', '백', '(', 'TQ', '18', ')'], tags='358'),
#  TaggedDocument(words=['삭루츠', '투', '웨이', '백', '팩', '(', 'TQ', '55', ')'], tags='359'),
#  TaggedDocument(words=['바다', '먹자', '국내', '산', '손질', '문어', '9', '팩'], tags='360'),
#  TaggedDocument(words=['CERINI', 'by', 'PAT', '남성', '어반', '카라', '티셔츠', '4', '종'], tags='361'),
#  TaggedDocument(words=['일', '시불', '엘지', '코드', '제로', '무선', '청소기', 'A', '950', '(', 'A', '958', 'IA', ')', '더블', '팩'], tags='362'),
#  TaggedDocument(words=['무', '이자', '엘지', '코드', '제로', '무선', '청소기', 'A', '950', '(', 'A', '958', 'IA', ')', '더블', '팩'], tags='363'),
#  TaggedDocument(words=['일', '시불', '엘지', '코드', '제로', '무선', '청소기', 'A', '940', '(', 'A', '948', 'SA', ')', '더블', '팩'], tags='364'),
#  TaggedDocument(words=['무', '이자', '엘지', '코드', '제로', '무선', '청소기', 'A', '940', '(', 'A', '948', 'SA', ')', '더블', '팩'], tags='365'),
#  TaggedDocument(words=['일', '시불', '엘지', '코드', '제로', '무선', '청소기', 'A', '930', '(', 'A', '938', 'RA', ')', '싱글', '팩'], tags='366'),
#  TaggedDocument(words=['푸마', '언더셔츠', '7', '종', '패키지'], tags='367'),
#  TaggedDocument(words=['일', '시불', '2019년', '올', '뉴', '숀리', '스쿼트', '머신'], tags='368'),
#  TaggedDocument(words=['무', '이자', '2019년', '올', '뉴', '숀리', '스쿼트', '머신'], tags='369'),
#  TaggedDocument(words=['도스', '문', '도스', '카이만', '엠보', '소', '가죽', '핸드백', '1', '종', '(', 'SS', ')'], tags='370'),
#  TaggedDocument(words=['스프리스', '여성', '코트', '스니커즈'], tags='371'),
#  TaggedDocument(words=['스프리스', '남성', '코트', '스니커즈'], tags='372'),
#  TaggedDocument(words=['아주', '아', '니트', '앙상블', '2', '종'], tags='373'),
#  TaggedDocument(words=['푸마', '드라이', '셀', '컴', '포트', '탑', '레이어', '브라', '탑', '4', '종', '세트', '(', '긴', '팔', '형', ')'], tags='374'),
#  TaggedDocument(words=['푸마', '드라이', '셀', '브라', '탑', '4', '종', '세트', '(', '런닝형', ')'], tags='375'),
#  TaggedDocument(words=['푸마', '드라이', '셀', '브라', '탑', '4', '종', '세트', '(', '끈', '형', ')'], tags='376'),
#  TaggedDocument(words=['일', '시불', '엘지', '울트라', '에이치', '디', '티비', '75', 'UK', '6200', 'KNB'], tags='377'),
#  TaggedDocument(words=['무', '이자', '엘지', '울트라', '에이치', '디', '티비', '75', 'UK', '6200', 'KNB'], tags='378'),
#  TaggedDocument(words=['키친', '아트', '스마트', '뷰', '스텐', '밀폐', '용기', '20', '종'], tags='379'),
#  TaggedDocument(words=['키친', '아트', '스마트', '뷰', '스텐', '밀폐', '용기', '9', '종'], tags='380'),
#  TaggedDocument(words=['일', '시불', '엘지', '휘센', '에어컨', '위너', 'FQ', '17', 'V', '8', 'WWJ', '2', '(', '2', 'in', '1', ')'], tags='381'),
#  TaggedDocument(words=['무', '이자', '엘지', '휘센', '에어컨', '위너', 'FQ', '17', 'V', '8', 'WWJ', '2', '(', '2', 'in', '1', ')'], tags='382'),
#  TaggedDocument(words=['무', '이자', '엘지', '휘센', '에어컨', '위너', 'FQ', '17', 'V', '8', 'WWJ', '1', '(', '스탠드', ')'], tags='383'),
#  TaggedDocument(words=['무', '이자', '삼성', '블루', '스카이', '공기청정기', '7000', 'AX', '80', 'R', '7580', 'WDD'], tags='384'),
#  TaggedDocument(words=['일', '시불', '삼성', '블루', '스카이', '공기청정기', '7000', 'AX', '80', 'R', '7580', 'WDD'], tags='385'),
#  TaggedDocument(words=['엘지', '휘센', '에어컨', '위너', 'FQ', '17', 'V', '9', 'WWA', '1', '(', '스탠드', ')'], tags='386'),
#  TaggedDocument(words=['오', '모', '떼', '프런트', '후크', '프레', '쉬', '데', '오브', '라', '시즌', '3'], tags='387'),
#  TaggedDocument(words=['스포', '메', '틱', '스', '네츄럴', '선', '스틱'], tags='388'),
#  TaggedDocument(words=['(', '쿠', ')', '일', '시불', '19년', '신제품', '쿠첸', '풀스텐', '압력밥솥', '10', '인용', '(', 'A', '1', ')'], tags='389'),
#  TaggedDocument(words=['(', '쿠', ')', '무', '이자', '19년', '신제품', '쿠첸', '풀스텐', '압력밥솥', '10', '인용', '(', 'A', '1', ')'], tags='390'),
#  TaggedDocument(words=['(', '쿠', ')', '일', '시불', '쿠첸', '압력밥솥', '6', '인용', '(', 'A', '1', ')'], tags='391'),
#  TaggedDocument(words=['(', '쿠', ')', '무', '이자', '쿠첸', '압력밥솥', '6', '인용', '(', 'A', '1', ')'], tags='392'),
#  TaggedDocument(words=['일', '시불', '삼성', '무풍', '슬림', '홈', '멀티', '에어컨', 'AF', '16', 'R', '5773', 'WSR'], tags='393'),
#  TaggedDocument(words=['무', '이자', '삼성', '무풍', '슬림', '홈', '멀티', '에어컨', 'AF', '16', 'R', '5773', 'WSR'], tags='394'),
#  TaggedDocument(words=['일', '시불', '삼성', '무풍', '슬림', '스탠드', '에어컨', 'AF', '16', 'R', '5773', 'WSK'], tags='395'),
#  TaggedDocument(words=['무', '이자', '삼성', '무풍', '슬림', '스탠드', '에어컨', 'AF', '16', 'R', '5773', 'WSK'], tags='396'),
#  TaggedDocument(words=['테이', '트', '여성', '티셔츠', '4', '종'], tags='397'),
#  TaggedDocument(words=['쿠', '미투', '니', '카', '라이크라', '보정', '레이스', '멀티', '팬티'], tags='398'),
#  TaggedDocument(words=['일', '시불', '종근당', '건강', '락토핏', '생', '유산균', '골드', '단', '하루'], tags='399'),
#  TaggedDocument(words=['무', '이자', '종근당', '건강', '락토핏', '생', '유산균', '골드', '단', '하루'], tags='400'),
#  TaggedDocument(words=['무', '이자', '엘지', '코드', '제로', '무선', '청소기', 'A', '930', '(', 'A', '938', 'RA', ')', '싱글', '팩'], tags='401'),
#  TaggedDocument(words=['K', '-', 'SWISS', '남성', '에어', '핏', '트랙', '수트'], tags='402'),
#  TaggedDocument(words=['K', '-', 'SWISS', '여성', '에어', '핏', '트랙', '수트'], tags='403'),
#  TaggedDocument(words=['영산포', '숙성', '홍어', '13', '팩'], tags='404'),
#  TaggedDocument(words=['K', '-', 'SWISS', '남성', '이', '너', '티셔츠', '5', '종'], tags='405'),
#  TaggedDocument(words=['K', '-', 'SWISS', '여성', '이', '너', '티셔츠', '5', '종'], tags='406'),
#  TaggedDocument(words=['K', '-', 'SWISS', '남성', '아웃도어', '팬츠', '3', '종'], tags='407'),
#  TaggedDocument(words=['K', '-', 'SWISS', '여성', '아웃도어', '팬츠', '3', '종'], tags='408'),
#  TaggedDocument(words=['무', ')', '한', '샘', '하이', '바스', '내추럴', '기본', '형'], tags='409'),
#  TaggedDocument(words=['일', ')', '한', '샘', '하이', '바스', '내추럴', '기본', '형'], tags='410'),
#  TaggedDocument(words=['무', ')', '한', '샘', '하이', '바스', '내추럴', '하부', '장형'], tags='411'),
#  TaggedDocument(words=['일', ')', '한', '샘', '하이', '바스', '내추럴', '하부', '장형'], tags='412'),
#  TaggedDocument(words=['무', ')', '한', '샘', '하이', '바스', '내추럴', '기본', '형', '+', '키', '큰', '장'], tags='413'),
#  TaggedDocument(words=['일', ')', '한', '샘', '하이', '바스', '내추럴', '기본', '형', '+', '키', '큰', '장'], tags='414'),
#  TaggedDocument(words=['BBC', '&', 'IZUMI', '레이', '스런', '닝', '브라', '패키지'], tags='415'),
#  TaggedDocument(words=['비버리힐스', '폴로', '클럽', '남성', '기초', '세트', '(', '골드', '+', '플', '라', ')'], tags='416'),
#  TaggedDocument(words=['델첸', '4', 'in', '1', '텀블러', '블', '랜더'], tags='417'),
#  TaggedDocument(words=['스피드', '랙', '베이직', '4', '단'], tags='418'),
#  TaggedDocument(words=['스피드', '랙', '베이직', '4', '단', '1', '+', '1'], tags='419'),
#  TaggedDocument(words=['베스트', '하임', '더', '담백한', '에어', '프라이어', '대', '용량', '5.5', 'L'], tags='420'),
#  TaggedDocument(words=['로베르', '타', '디', '까', '메리노', 'Y', '밸런스', '업', '지퍼', '쉐이핑', '란쥬'], tags='421'),
#  TaggedDocument(words=['김병만', '의', '정글', '피싱', '낚시', '세트'], tags='422'),
#  TaggedDocument(words=['[', '플', '로쥬', ']', '트윙클', '아일렛', '스니커즈'], tags='423'),
#  TaggedDocument(words=['컬럼비아', '남성', '베이스', '레이어', '5', '종'], tags='424'),
#  TaggedDocument(words=['컬럼비아', '여성', '베이스', '레이어', '5', '종'], tags='425'),
#  TaggedDocument(words=['일', '시불', '해피', '콜', '크로커다일', 'IH', '후라이팬'], tags='426'),
#  TaggedDocument(words=['무', '이자', '해피', '콜', '크로커다일', 'IH', '후라이팬'], tags='427'),
#  TaggedDocument(words=['이만기', '의', '리얼', '국밥', '3', '종', '27', '팩'], tags='428'),
#  TaggedDocument(words=['월드컵', '남성', '19', 'SS', '트레킹', '화'], tags='429'),
#  TaggedDocument(words=['월드컵', '여성', '19', 'SS', '트레킹', '화'], tags='430'),
#  TaggedDocument(words=['일', '시불', '[', '가이거', ']', '무빙', '스타', '다이아몬드', '워치'], tags='431'),
#  TaggedDocument(words=['무', '이자', '[', '가이거', ']', '무빙', '스타', '다이아몬드', '워치'], tags='432'),
#  TaggedDocument(words=['네페르티티', '유기농', '퀸', '석류', '즙', '6', '박스'], tags='433'),
#  TaggedDocument(words=['제옥스', '남성', '가죽', '스니커즈'], tags='434'),
#  TaggedDocument(words=['제옥스', '여성', '어', '글리', '스니커즈'], tags='435'),
#  TaggedDocument(words=['김병지', '거미', '손', '풀', '확장', '일체', '형', '코일', '카', '매트'], tags='436'),
#  TaggedDocument(words=['마리', '끌', '레르', '파리', '컬렉션', '리얼', '하', '이드', '로', '립스틱', '(', '2019', '리뉴얼', ')'], tags='437'),
#  TaggedDocument(words=['리복', '스피드', '윅', '드로즈', '12', '종'], tags='438'),
#  TaggedDocument(words=['리복', '델타', '피트니스', '트렁크', '8', '종'], tags='439'),
#  TaggedDocument(words=['리복', '스피드', '윅', '런닝', '6', '종'], tags='440'),
#  TaggedDocument(words=['일', '시불', '삼성', '유', '에이치', '디', '티비', 'UN', '55', 'NU', '7050', 'F'], tags='441'),
#  TaggedDocument(words=['무', '이자', '삼성', '유', '에이치', '디', '티비', 'UN', '55', 'NU', '7050', 'F'], tags='442'),
#  TaggedDocument(words=['일', '시불', '삼성', '유', '에이치', '디', '티비', 'UN', '65', 'NU', '7050', 'F'], tags='443'),
#  TaggedDocument(words=['무', '이자', '삼성', '유', '에이치', '디', '티비', 'UN', '65', 'NU', '7050', 'F'], tags='444'),
#  TaggedDocument(words=['무', '이자', '삼성', '유', '에이치', '디', '티비', 'UN', '75', 'NU', '7050', 'F'], tags='445'),
#  TaggedDocument(words=['일', '시불', '삼성', '유', '에이치', '디', '티비', 'UN', '75', 'NU', '7050', 'F'], tags='446'),
#  TaggedDocument(words=['아', '리스', '토우', '남성', '오가', '닉', '티셔츠'], tags='447'),
#  TaggedDocument(words=['아', '리스', '토우', '여', '성오', '가', '닉', '티셔츠'], tags='448'),
#  TaggedDocument(words=['로베르', '타', '디', '까', '메리노', '메쉬', '프리', '컷', '지퍼', '브라', '팬티'], tags='449'),
#  TaggedDocument(words=['더블유', '베일', '소프트', '마카롱', '니트', '5', '종'], tags='450'),
#  TaggedDocument(words=['제옥스', '남성', '가죽', '스니커즈', '(', 'V', ')'], tags='451'),
#  TaggedDocument(words=['제옥스', '여성', '어', '글리', '스니커즈', '(', 'V', ')'], tags='452'),
#  TaggedDocument(words=['[', '살롱', '클리', '닉', ']', '샤이닝', '트리트먼트', '헤어', '컬러', '크림', '세트'], tags='453'),
#  TaggedDocument(words=['일', '시불', '올리고', '가스', '와이드', '그릴', '프리미엄', '형'], tags='454'),
#  TaggedDocument(words=['무', '이자', '올리고', '가스', '와이드', '그릴', '레인지', '프리미엄', '형'], tags='455'),
#  TaggedDocument(words=['에이', '유플러스', '슈퍼', '선', '스틱', '1001', '(', '쇼퍼', '백', ')'], tags='456'),
#  TaggedDocument(words=['푸마', '코튼', '언', '더탑', '9', '종'], tags='457'),
#  TaggedDocument(words=['엘지', '생활', '건강', '건조기', '시트', '퍼퓸', '드몽드'], tags='458'),
#  TaggedDocument(words=['[', '본', '죽', ']', '그때', '그', '쇠고기', '장조림', '세트', '(', '총', '13', '팩', ')'], tags='459'),
#  TaggedDocument(words=['디', '키즈', '윈드브레이커', '1', '종'], tags='460'),
#  TaggedDocument(words=['파뷔', '에', '항균', '도마', '1', '+', '1', '세트'], tags='461'),
#  TaggedDocument(words=['일', '시불', '삼성', '5', '도어', '냉장고', 'H', '9000', 'RH', '81', 'M', '8011', 'S', '9'], tags='462'),
#  TaggedDocument(words=['무', '이자', '삼성', '5', '도어', '냉장고', 'H', '9000', 'RH', '81', 'M', '8011', 'S', '9'], tags='463'),
#  TaggedDocument(words=['일', '시불', '삼성', '엑티브워시', '세탁기', '14', 'kg', 'WA', '14', 'N', '6781', 'TG'], tags='464'),
#  TaggedDocument(words=['무', '이자', '삼성', '엑티브워시', '세탁기', '14', 'kg', 'WA', '14', 'N', '6781', 'TG'], tags='465'),
#  TaggedDocument(words=['크로커다일', '감탄', '레이스', '브라', '렛', '패키지'], tags='466'),
#  TaggedDocument(words=['밀싹', '클', '렌즈', '8', '박스', ',', '8', '주', '분', '!', '+', '전용', '보틀'], tags='467'),
#  TaggedDocument(words=['디', '키즈', '성인', '스', '테디', '움', '점퍼', '세트'], tags='468'),
#  TaggedDocument(words=['디', '키즈', '아동', '스', '테디', '움', '점퍼', '세트'], tags='469'),
#  TaggedDocument(words=['CERINI', 'by', 'PAT', '남성', '캐', '주얼', '셔츠', '4', '종'], tags='470'),
#  TaggedDocument(words=['일', '시불', '엘', '지스', '타일러', '의류', '관리', '기', '(', '5', '벌', ')', 'S', '5', 'BB'], tags='471'),
#  TaggedDocument(words=['무', '이자', '엘', '지스', '타일러', '의류', '관리', '기', '(', '5', '벌', ')', 'S', '5', 'BB'], tags='472'),
#  TaggedDocument(words=['무', '이자', '엘', '지스', '타일러', '의류', '관리', '기'], tags='473'),
#  TaggedDocument(words=['일', '시불', '엘', '지스', '타일러', '의류', '관리', '기'], tags='474'),
#  TaggedDocument(words=['스텔라', '테일러', '컴', '포트', '스트레치', '팬츠', '3', '종'], tags='475'),
#  TaggedDocument(words=['일', '시불', '19년', '신제품', '쿠첸', '풀스텐', '압력밥솥', '10', '인용', '(', 'A', '1', ')'], tags='476'),
#  TaggedDocument(words=['무', '이자', '19년', '신제품', '쿠첸', '풀스텐', '압력밥솥', '10', '인용', '(', 'A', '1', ')'], tags='477'),
#  TaggedDocument(words=['일', '시불', '쿠첸', '압력밥솥', '6', '인용', '(', 'A', '1', ')'], tags='478'),
#  TaggedDocument(words=['무', '이자', '쿠첸', '압력밥솥', '6', '인용', '(', 'A', '1', ')'], tags='479'),
#  TaggedDocument(words=['피시', '원', '국내', '산', '손질', '꽃게', '7', '팩'], tags='480'),
#  TaggedDocument(words=['(', '일', ')', '보루', '네오', '유로', '탑', '가죽', '침대', '슈퍼', '싱글'], tags='481'),
#  TaggedDocument(words=['(', '일', ')', '보루', '네오', '유로', '탑', '가죽', '침대', '퀸'], tags='482'),
#  TaggedDocument(words=['(', '무', ')', '보루', '네오', '유로', '탑', '가죽', '침대', '퀸'], tags='483'),
#  TaggedDocument(words=['(', '일', ')', '보루', '네오', '유로', '탑', '가죽', '침대', '킹'], tags='484'),
#  TaggedDocument(words=['(', '무', ')', '보루', '네오', '유로', '탑', '가죽', '침대', '킹'], tags='485'),
#  TaggedDocument(words=['(', '무', ')', '보루', '네오', '유로', '탑', '가죽', '침대', '슈퍼', '싱글'], tags='486'),
#  TaggedDocument(words=['19', 'SS', 'USPA', '남성', '화이트', '라벨', '폴로셔츠', '3', '종'], tags='487'),
#  TaggedDocument(words=['19', 'SS', 'USPA', '여성', '화이트', '라벨', '폴로셔츠', '3', '종'], tags='488'),
#  TaggedDocument(words=['일', '시불', '메디', '컬', '드림', '롤링', '마사지', '기', '(', 'KMD', '-', '970', ')'], tags='489'),
#  TaggedDocument(words=['무', '이자', '메디', '컬', '드림', '롤링', '마사지', '기', '(', 'KMD', '-', '970', ')'], tags='490'),
#  TaggedDocument(words=['레코바', '남성', '다이얼', '워킹', '화', '세트'], tags='491'),
#  TaggedDocument(words=['레코바', '여성', '다이얼', '워킹', '화', '세트'], tags='492'),
#  TaggedDocument(words=['스포', '메', '틱', '스', '트리플', '샤이닝', '쿠션', '(', '이데베논앰플', ')'], tags='493'),
#  TaggedDocument(words=['일', '시불', '해피', '콜', '아르마', '이드', 'IH', '냄비'], tags='494'),
#  TaggedDocument(words=['무', '이자', '해피', '콜', '아르마', '이드', 'IH', '냄비'], tags='495'),
#  TaggedDocument(words=['오렐', '리안', '풍기', '인견', '란쥬', '패키지'], tags='496'),
#  TaggedDocument(words=['로베르', '타', '디', '까', '메리노', '수피', '마', '코튼', '프리', '컷', '브라', '팬티'], tags='497'),
#  TaggedDocument(words=['(', '무', ')', '한', '샘', '하이', '바스', '내추럴', '기본', '형'], tags='498'),
#  TaggedDocument(words=['(', '일', ')', '한', '샘', '하이', '바스', '내추럴', '기본', '형'], tags='499'),
#  TaggedDocument(words=['(', '무', ')', '한', '샘', '하이', '바스', '내추럴', '하부', '장형'], tags='500'),
#  TaggedDocument(words=['(', '무', ')', '한', '샘', '하이', '바스', '내추럴', '기본', '형', '+', '키', '큰', '장'], tags='501'),
#  TaggedDocument(words=['(', '무', ')', '한', '샘', '하이', '바스', '내추럴', '하부', '장', '+', '키', '큰', '장'], tags='502'),
#  TaggedDocument(words=['트레스패스', '여성', '다이얼', '트레킹', '화', '세트'], tags='503'),
#  TaggedDocument(words=['트레스패스', '남성', '다이얼', '트레킹', '화', '세트'], tags='504'),
#  TaggedDocument(words=['뷰티플', '렉스', '풍기', '인견', '브라', '탑', '패키지'], tags='505'),
#  TaggedDocument(words=['(', '일', ')[', '안드레아', '바나', ']', '리얼', '카이만', '악어', '토트', '백'], tags='506'),
#  TaggedDocument(words=['(', '무', ')[', '안드레아', '바나', ']', '리얼', '카이만', '악어', '토트', '백'], tags='507'),
#  TaggedDocument(words=['[', '안드레아', '바나', ']', '리얼', '카이만', '악어', '바디', '숄더백'], tags='508'),
#  TaggedDocument(words=['[', '안드레아', '바나', ']', '리얼', '카이만', '악어', '테일', '숄더백'], tags='509'),
#  TaggedDocument(words=['실크', '트리', '풍기', '인견', '데', '일리', '쿨', '이', '지', '탑', '패키지'], tags='510'),
#  TaggedDocument(words=['속초', '명물', '티', '각', '태각', '부각', '6', '종', ',', '30', '봉'], tags='511'),
#  TaggedDocument(words=['뱅뱅', '남성', '아웃도어', '팬츠', '3', '종', '(', '2019', 'S', '/', 'S', ')'], tags='512'),
#  TaggedDocument(words=['뱅뱅', '여성', '아웃도어', '팬츠', '3', '종', '(', '2019', 'S', '/', 'S', ')'], tags='513'),
#  TaggedDocument(words=['레이', '프릴', '쿨', '보정', '런닝'], tags='514'),
#  TaggedDocument(words=['삭루츠', '토트', '백', '(', 'TQ', '35', ')'], tags='515'),
#  TaggedDocument(words=['보몽', '드', '순면', '60', '수', '피그먼트워싱', '침구', '세트', 'SS'], tags='516'),
#  TaggedDocument(words=['보몽', '드', '순면', '60', '수', '피그먼트워싱', '침구', '세트', 'Q'], tags='517'),
#  TaggedDocument(words=['보몽', '드', '순면', '60', '수', '피그먼트워싱', '침구', '세트', 'K'], tags='518'),
#  TaggedDocument(words=['영광', '生', '모시', '떡', '100', '개', '!!(', '동부', '기피', '70', '개', '+', '검정', '깨', '30', '개', ')'], tags='519'),
#  TaggedDocument(words=['영광', '生', '모시', '떡', '90', '개', '+', '찰보리', '식혜', '(', '동부', '기피', '70', '개', '+', '검정', '깨', '20', '개', ')'], tags='520'),
#  TaggedDocument(words=['시크릿', '라', '메종', '볼륨', '스프레이', '(', '고데기', ')'], tags='521'),
#  TaggedDocument(words=['보코', '배색', '사파리', '재킷'], tags='522'),
#  TaggedDocument(words=['무', '이자', '전기', '식', '회', '전통', '그릴', '드럼', '쿡'], tags='523'),
#  TaggedDocument(words=['일', '시불', '전기', '식', '회', '전통', '그릴', '드럼', '쿡'], tags='524'),
# ...
#  TaggedDocument(words=['무', '이자', '매직', '쉐프', '플랫', '타입', '전자레인지'], tags='827'),
#  TaggedDocument(words=['일', '시불', '매직', '쉐프', '플랫', '타입', '전자레인지'], tags='828'),
#  TaggedDocument(words=['리복', '델타', '언더셔츠', '6', '종', '패키지'], tags='829'),
#  TaggedDocument(words=['일', '시불', '휴롬퀵스퀴저'], tags='830'),
#  TaggedDocument(words=['무', '이자', '휴롬', '퀵스퀴저'], tags='831'),
#  TaggedDocument(words=['무', '이자', '아이', '넥스', '솔리드', '멀티', '식기', '건조대'], tags='832'),
#  TaggedDocument(words=['일', '시불', '아이', '넥스', '솔리드', '멀티', '식기', '건조대'], tags='833'),
#  TaggedDocument(words=['국내', '산', '손질', '병어', '26', '미'], tags='834'),
#  TaggedDocument(words=['이경제', '의', '황제', '진액', '철갑상어', '120', '포'], tags='835'),
#  TaggedDocument(words=['(', '일', '시불', ')', '헤드', '언더셔츠', '6', '종', '패키지', '(', '7월', ')'], tags='836'),
#  TaggedDocument(words=['(', '무', '이자', ')', '헤드', '언더셔츠', '6', '종', '패키지', '(', '7월', ')'], tags='837'),
#  TaggedDocument(words=['코치', '리스', '틀릿'], tags='838'),
#  TaggedDocument(words=['코치', '베', '네트', '사', '첼', '백'], tags='839'),
#  TaggedDocument(words=['코치', '미네', '타', '크로스', '바디', '백'], tags='840'),
#  TaggedDocument(words=['코치', '엠마', '사', '첼', '백'], tags='841'),
#  TaggedDocument(words=['코치', '시', '그', '니', '처', '켈시', '사', '첼', '백'], tags='842'),
#  TaggedDocument(words=['무', '이자', '에코', '바이런', '호주', '원목', '캄', '포도', '마', '3', '종', '세트'], tags='843'),
#  TaggedDocument(words=['일', '시불', '에코', '바이런', '호주', '원목', '캄', '포도', '마', '3', '종', '세트'], tags='844'),
#  TaggedDocument(words=['무', '이자', '에코', '바이런', '호주', '원목', '대형', '캄', '포도', '마', '1', '종'], tags='845'),
#  TaggedDocument(words=['도스', '문', '도스', '카이만', '엠보', '소', '가죽', '핸드백', '1', '종', '(', '역', '시즌', ')'], tags='846'),
#  TaggedDocument(words=['유', '귀', '열의', 'The', '귀한', '갓김치', '3', 'kg', '+', '열무김치', '3', 'kg', ',', '총', '6', 'kg'], tags='847'),
#  TaggedDocument(words=['웰스', '락', '원', '터치', '슬라이드', '특허', '밀폐', '용기', '세트'], tags='848'),
#  TaggedDocument(words=['엘렌', '실라', '에스', '까', '르', '고', '에센스', '커버', '쿠션'], tags='849'),
#  TaggedDocument(words=['레이', '프릴', '핏', '쿨', '브라', '패키지'], tags='850'),
#  TaggedDocument(words=['마', '스케', '라', '썸머', '컬렉션', '4', '종', '(', '모자', '2', '종', '+', '핸드백', '1', '종', '+', '스카프', '1', '종', ')'], tags='851'),
#  TaggedDocument(words=['코몽트', '남성', '메쉬', '티셔츠', '7', '종'], tags='852'),
#  TaggedDocument(words=['안지', '청풍', '대자리'], tags='853'),
#  TaggedDocument(words=['뱅뱅', '남성', '크롭', '아웃도어', '팬츠', '3', '종', '(', '2019', 'S', '/', 'S', ')'], tags='854'),
#  TaggedDocument(words=['뱅뱅', '여성', '크롭', '아웃도어', '팬츠', '3', '종', '(', '2019', 'S', '/', 'S', ')'], tags='855'),
#  TaggedDocument(words=['(', '세', '일', '20%', ')', '푸마', '언더셔츠', '7', '종', '패키지', '(', '1-1', '차', ')'], tags='856'),
#  TaggedDocument(words=['레이', '프릴', '네추럴', '쿨', '쉐이핑', '브라', '패키지'], tags='857'),
#  TaggedDocument(words=['일', '시불', '엘지', '전자', '휴대', '용', '퓨리', '케어', '미니', '공', '청기'], tags='858'),
#  TaggedDocument(words=['무', '이자', '엘지', '전자', '휴대', '용', '퓨리', '케어', '미니', '공', '청기'], tags='859'),
#  TaggedDocument(words=['AAD', '소', '가죽', '투', '웨이', '샌들'], tags='860'),
#  TaggedDocument(words=['일', '시불', '삼성', '무풍', '클래식', '홈', '멀티', '에어컨', 'AF', '19', 'R', '7573', 'WZR'], tags='861'),
#  TaggedDocument(words=['일', '시불', '삼성', '무풍', '클래식', '홈', '멀티', '에어컨', 'AF', '17', 'R', '7573', 'WZR'], tags='862'),
#  TaggedDocument(words=['무', '이자', '삼성', '무풍', '클래식', '홈', '멀티', '에어컨', 'AF', '19', 'R', '7573', 'WZR'], tags='863'),
#  TaggedDocument(words=['무', '이자', '삼성', '무풍', '클래식', '홈', '멀티', '에어컨', 'AF', '17', 'R', '7573', 'WZR'], tags='864'),
#  TaggedDocument(words=['무', '이자', '삼성', '무풍', '클래식', '스탠드', '에어컨', 'AF', '17', 'R', '7573', 'WZK'], tags='865'),
#  TaggedDocument(words=['AAD', '여성', '소', '가죽', '구름', '샌들'], tags='866'),
#  TaggedDocument(words=['AAD', '남성', '소', '가죽', '구름', '샌들'], tags='867'),
#  TaggedDocument(words=['키친', '플라워', '그린', '후', '레쉬', '세트'], tags='868'),
#  TaggedDocument(words=['창녕', '마늘', '양파', '듬뿍', '삼계탕', '1', 'kg', ',', '6', '팩'], tags='869'),
#  TaggedDocument(words=['무', '이자', '하우', '홈', '초', '고속', '진공', '쿠킹', '블렌더'], tags='870'),
#  TaggedDocument(words=['일', '시불', '하우', '홈', '초', '고속', '진공', '쿠킹', '블렌더'], tags='871'),
#  TaggedDocument(words=['리복', '스피드', '윅', '에어리', '라이트', '브라', '&', '숏츠', '패키지'], tags='872'),
#  TaggedDocument(words=['일', '시불', 'am', '마카롱', '보냉', '보온', '텀블러', '세트'], tags='873'),
#  TaggedDocument(words=['무', '이자', 'am', '마카롱', '보냉', '보온', '텀블러', '세트'], tags='874'),
#  TaggedDocument(words=['레', '노마', '우', '/', '양산', '2', '종', '세트'], tags='875'),
#  TaggedDocument(words=['남영', '비비안', '로즈버드', '듀얼', '윙', '스킨', '보정', '브라', '패키지'], tags='876'),
#  TaggedDocument(words=['두꺼비', '매직', '버블', '수세미', '400', '매', '+', '곰팡이', '젤', '2', '개'], tags='877'),
#  TaggedDocument(words=['두꺼비', '매직', '버블', '수세미', '200', '매', '+', '곰팡이', '젤', '1', '개'], tags='878'),
#  TaggedDocument(words=['루이띠', '에', '순금', '샤이닝', '러브', '목걸이', '35', 'g', '+', '골드바', '1', 'g'], tags='879'),
#  TaggedDocument(words=['루이띠', '에', '순금', '크로스', '트리플', '목걸이', '18', 'g', '+', '골드바', '1', 'g'], tags='880'),
#  TaggedDocument(words=['루이띠', '에', '순금', '크로스', '트리플', '팔찌', '18', 'g', '+', '골드바', '1', 'g'], tags='881'),
#  TaggedDocument(words=['루이띠', '에', '순금', '신', '디스', '틱', '목걸이', '13', 'g', '+', '골드바', '1', 'g'], tags='882'),
#  TaggedDocument(words=['루이띠', '에', '순금', '신', '디스', '틱', '팔찌', '13', 'g', '+', '골드바', '1', 'g'], tags='883'),
#  TaggedDocument(words=['루이띠', '에', '순금', '샤이닝', '러브', '팔찌', '35', 'g', '+', '골드바', '1', 'g'], tags='884'),
#  TaggedDocument(words=['디', '키즈', '썸머', '숏', '팬츠', '3', '종'], tags='885'),
#  TaggedDocument(words=['1', '세트', '믹서', '를', '품은', '텀블러'], tags='886'),
#  TaggedDocument(words=['2', '세트', '믹서', '를', '품은', '텀블러'], tags='887'),
#  TaggedDocument(words=['EXR', '남성', '워터', '액', '티비', '티', '5', '종'], tags='888'),
#  TaggedDocument(words=['EXR', '여성', '워터', '액', '티비', '티', '5', '종'], tags='889'),
#  TaggedDocument(words=['카파', '드로즈', '패키지', '10', '종', '(', '3', '차', ')'], tags='890'),
#  TaggedDocument(words=['코몽트', '남성', '프린트', '티셔츠', '8', '종'], tags='891'),
#  TaggedDocument(words=['루이띠', '에', '순금', '미라클', '트리플', '링', '15', 'g', '+', '골드바', '1', 'g'], tags='892'),
#  TaggedDocument(words=['월드컵', '여성', '에어', '러닝', '화', '+', '아쿠아', '트레킹', '화'], tags='893'),
#  TaggedDocument(words=['월드컵', '남성', '에어', '러닝', '화', '+', '아쿠아', '트레킹', '화'], tags='894'),
#  TaggedDocument(words=['참', '존', '탑', '뉴스', '지', '이', '링클', '기초', '세트'], tags='895'),
#  TaggedDocument(words=['국내', '제조', '오슬로', 'IH', '프라이팬', '세트'], tags='896'),
#  TaggedDocument(words=['황', '토방', '청도', '감', '말랭이', '30', '봉', '+', '무료', '체험', '1', '봉', ',', '총', '31', '봉'], tags='897'),
#  TaggedDocument(words=['무', '이자', '엘지', '울트라', '에이치', '디', '티비', '75', 'UK', '7400', 'KNA'], tags='898'),
#  TaggedDocument(words=['일', '시불', '2019년', '타이거', '충전', '식', '무선', '예', '초기'], tags='899'),
#  TaggedDocument(words=['무', '이자', '2019년', '타이거', '충전', '식', '무선', '예', '초기'], tags='900'),
#  TaggedDocument(words=['일', '시불', '2019년', '타이거', '충전', '식', '무선', '예', '초기', '+', '배터리', '1', '개'], tags='901'),
#  TaggedDocument(words=['무', '이자', '2019년', '타이거', '충전', '식', '무선', '예', '초기', '+', '배터리', '1', '개'], tags='902'),
#  TaggedDocument(words=['효재', '화원', '자수', '광목', '워싱', '침구', '세트', '킹'], tags='903'),
#  TaggedDocument(words=['효재', '화원', '자수', '광목', '워싱', '침구', '세트', '퀸'], tags='904'),
#  TaggedDocument(words=['효재', '화원', '자수', '광목', '워싱', '침구', '세트', '슈퍼', '싱글'], tags='905'),
#  TaggedDocument(words=['티젠', '히비스커스', '분말'], tags='906'),
#  TaggedDocument(words=['안타', '고', '만능', '가스', '그릴'], tags='907'),
#  TaggedDocument(words=['무', '이자', '쿠쿠', '전기밥솥', '10', '인용', '(', 'CRP', '-', 'QS', '107', 'FG', '/', 'FS', ')'], tags='908'),
#  TaggedDocument(words=['일', '시불', '쿠쿠', '전기밥솥', '10', '인용', '(', 'QS', ')'], tags='909'),
#  TaggedDocument(words=['무', '이자', '쿠쿠', '전기밥솥', '6', '인용', '(', 'QS', ')'], tags='910'),
#  TaggedDocument(words=['일', '시불', '쿠쿠', '전기밥솥', '6', '인용', '(', 'QS', ')'], tags='911'),
#  TaggedDocument(words=['라', '쉬반', '뉴트', '로', '에어', '에디', '션', '드로즈', '패키지'], tags='912'),
#  TaggedDocument(words=['라', '쉬반', '레알마드리드', '에디', '션', '드로즈', '패키지'], tags='913'),
#  TaggedDocument(words=['팜스프링스', '19', 'SS', '남성', '여름', '쿨', '팬츠', '4', '종'], tags='914'),
#  TaggedDocument(words=['팜스프링스', '19', 'SS', '여성', '여름', '쿨', '팬츠', '4', '종'], tags='915'),
#  TaggedDocument(words=['뉴욕', '맘', '항균', '수세미'], tags='916'),
#  TaggedDocument(words=['몬테', '밀라노', '크루즈', '이', '지', '웨어', '패키지'], tags='917'),
#  TaggedDocument(words=['디즈니', '19', 'SS', '반', '팔', '스웻', '티셔츠', '6', '종'], tags='918'),
#  TaggedDocument(words=['일', '시불', '엘지', '울트라', '에이치', '디', '티비', '75', 'UK', '7400', 'KNA'], tags='919'),
#  TaggedDocument(words=['생줄', '랑', '14', 'K', '글로리아', '목걸이', '컬렉션', '8', '종'], tags='920'),
#  TaggedDocument(words=['푸마', 'DRY', '-', 'CELL', '에센셜', '브라', '팬티', '7', '세트', '(', '복합', '구성', ')'], tags='921'),
#  TaggedDocument(words=['푸마', 'DRY', '-', 'CELL', '에센셜', '브라', '팬티', '7', '세트', '(', '스킨', '구성', ')'], tags='922'),
#  TaggedDocument(words=['대동', '모피', '19', 'F', '/', 'W', '폭스', '베스트'], tags='923'),
#  TaggedDocument(words=['헤스', '티', '지', '미즈', '양', '가죽', '롱', '코트'], tags='924'),
#  TaggedDocument(words=['깐', '깐', '송도순', '포기', '김치', '10', 'kg'], tags='925'),
#  TaggedDocument(words=['깐', '깐', '송도순', '포기', '김치', '8', 'kg', '+', '백김치', '2', 'kg'], tags='926'),
#  TaggedDocument(words=['이동수', '골프', '남성', '썸머', '밴딩', '팬츠', '3', '종'], tags='927'),
#  TaggedDocument(words=['이동수', '골프', '여성', '썸머', '밴딩', '팬츠', '3', '종'], tags='928'),
#  TaggedDocument(words=['스포', '메', '틱', '스', '트리플', '샤이닝', '쿠션', '시즌', '1'], tags='929'),
#  TaggedDocument(words=['헤드', '파이', '로', '라이트', '드로즈', '10', '종', '패키지', '(', '7월', ')'], tags='930'),
#  TaggedDocument(words=['헤드', '파이', '로', '라이트', '트렁크', '8', '종', '패키지', '(', '7월', ')'], tags='931'),
#  TaggedDocument(words=['이지', '엔', '슬라이더', '지퍼', '백'], tags='932'),
#  TaggedDocument(words=['임성근', '의', '녹용', '도가니탕', '풀', '세트'], tags='933'),
#  TaggedDocument(words=['일', '시불', '엘지', '전자', '노크', '온', '매직', '스페이스', '냉장고', 'S', '831', 'SN', '75'], tags='934'),
#  TaggedDocument(words=['무', '이자', '엘지', '전자', '노크', '온', '매직', '스페이스', '냉장고', 'S', '831', 'SN', '75'], tags='935'),
#  TaggedDocument(words=['오델로', '2019', '여', '성용', '여름', '모자', '3', '종'], tags='936'),
#  TaggedDocument(words=['마리', '노블', '밍크', '롱', '코트', '(', '역', '시즌', ')'], tags='937'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'K', '베르니', '아', '주얼리', '세트'], tags='938'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'K', '베르니', '아', '목걸이', '팔찌', '세트'], tags='939'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'K', '베르니', '아', '팔찌', '반지', '세트'], tags='940'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'K', '베르니', '아', '목걸이'], tags='941'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'K', '베르니', '아', '팔찌'], tags='942'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'K', '베르니', '아', '귀걸이'], tags='943'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'K', '베르니', '아', '반지'], tags='944'),
#  TaggedDocument(words=['뷰티플', '렉스', '풍기', '인견', '원피스', '2', '종', '(', '8월', ')'], tags='945'),
#  TaggedDocument(words=['푸마', 'DRY', '-', 'CELL', '퓨징', '슬림', '라이트', '브라', '패키지'], tags='946'),
#  TaggedDocument(words=['바로바로', '무선', '청소기', '+', '필터', '1', '개', '추가'], tags='947'),
#  TaggedDocument(words=['광동', '장', '건강', '엔', '생', '유산균'], tags='948'),
#  TaggedDocument(words=['일', '시불', '삼성', '4', '도어', '푸드', '쇼케이스', '냉장고', 'RH', '81', 'R', '8011', 'G', '2', '(+', '선풍기', ')'], tags='949'),
#  TaggedDocument(words=['무', '이자', '삼성', '4', '도어', '푸드', '쇼케이스', '냉장고', 'RH', '81', 'R', '8011', 'G', '2', '(+', '선풍기', ')'], tags='950'),
#  TaggedDocument(words=['3', 'D', '매쉬', '냉수', '마찰', '물', '매트'], tags='951'),
#  TaggedDocument(words=['마리', '노블', '밍크', '퍼', '베스트', '(', '역', '시즌', ')'], tags='952'),
#  TaggedDocument(words=['크리스티나', '앤코', '썸머', '플', '리츠', '세트', '(', '8월', ')'], tags='953'),
#  TaggedDocument(words=['일', '시불', '삼성', '무풍', '클래식', '스탠드', '에어컨', 'AF', '19', 'R', '7573', 'WZK'], tags='954'),
#  TaggedDocument(words=['무', '이자', '삼성', '무풍', '클래식', '스탠드', '에어컨', 'AF', '19', 'R', '7573', 'WZK'], tags='955'),
#  TaggedDocument(words=['[', '일', '시불', ']', '가이거', '무빙', '스타', '다이아몬드', '워치', '+', '보석', '함'], tags='956'),
#  TaggedDocument(words=['[', '무', '이자', ']', '가이거', '무빙', '스타', '다이아몬드', '워치', '+', '보석', '함'], tags='957'),
#  TaggedDocument(words=['로베르', '타', '디', '까', '메리노', '풀', '바스', '트', '업', '지퍼', '브라', '팬티'], tags='958'),
#  TaggedDocument(words=['오', '모', '떼', '쉐이핑', '브라', '팬티', '10', '종', '(', '7월', ')'], tags='959'),
#  TaggedDocument(words=['보코', '풍기', '인견', '블라우스'], tags='960'),
#  TaggedDocument(words=['해피', '콜', 'IH', '양면', '팬'], tags='961'),
#  TaggedDocument(words=['일', '시불', '해피', '콜', 'IH', '진공', '스텐', '냄비'], tags='962'),
#  TaggedDocument(words=['오가', '닉', '뷰티', '쿨', '번', '아웃', '레이스', '브라', '세트'], tags='963'),
#  TaggedDocument(words=['유', '귀', '열의', 'The', '귀한', '한우', '한판', '12', '팩'], tags='964'),
#  TaggedDocument(words=['마르', '엘라', '로', '사티', '휘', '메일', '풀', '스킨', '하이', '넥', '밍크', '코트', '1', '종'], tags='965'),
#  TaggedDocument(words=['생쥴', '랑', '14', 'K', '베스트', '귀걸이', '5', '종', '컬렉션', '(', '14', 'K', '골드', '5', '종', ')'], tags='966'),
#  TaggedDocument(words=['프라다', '투', '브릿지', '선글라스'], tags='967'),
#  TaggedDocument(words=['프라다', '미란다', '백'], tags='968'),
#  TaggedDocument(words=['프라다', '비텔', '로', '피닉스', '모터', '백'], tags='969'),
#  TaggedDocument(words=['프라다', '비텔', '로', '피닉스', '보스턴'], tags='970'),
#  TaggedDocument(words=['프라다', '테스', '토', '호보', '백'], tags='971'),
#  TaggedDocument(words=['골드', '파일', '카', '로', '여행', '가방', '9', '종', '세트'], tags='972'),
#  TaggedDocument(words=['AAB', '의', '든든한', '콩국수'], tags='973'),
#  TaggedDocument(words=['라라', '츄', '틴트', '아이브', '로우', '바'], tags='974'),
#  TaggedDocument(words=['레이', '프릴', '오가', '닉', '코튼', '보정', '팬티', '12', '종'], tags='975'),
#  TaggedDocument(words=['프라다', '피닉스', '토트', '숄더백'], tags='976'),
#  TaggedDocument(words=['프라다', '사', '피아노', '스퀘어', '백'], tags='977'),
#  TaggedDocument(words=['프라다', '테스', '토', '체인', '쇼퍼', '백'], tags='978'),
#  TaggedDocument(words=['프라다', '테스', '토', '지퍼', '토트', '백'], tags='979'),
#  TaggedDocument(words=['무', '이자', '에코', '라', '믹', '모던', 'IH', '냄비', '세트'], tags='980'),
#  TaggedDocument(words=['일', '시불', '에코', '라', '믹', '모던', 'IH', '냄비', '세트'], tags='981'),
#  TaggedDocument(words=['오렐', '리안', '풍기', '인견', '원피스', '2', '종', '세트', '(', '8월', ')'], tags='982'),
#  TaggedDocument(words=['무', '이자', '서장훈', '의', '락앤락', '칼', '도마', '살균', '블럭'], tags='983'),
#  TaggedDocument(words=['일', '시불', '서장훈', '의', '락앤락', '칼', '도마', '살균', '블럭'], tags='984'),
#  TaggedDocument(words=['(', '일', ')', '100%', '리얼', '착즙', '석류', '4', '박스'], tags='985'),
#  TaggedDocument(words=['(', '무', ')', '100%', '리얼', '착즙', '석류', '4', '박스'], tags='986'),
#  TaggedDocument(words=['푸마', '드라이', '셀', '브라', '탑', '4', '종', '세트', '(', '런닝형', ')(', '8월', ')'], tags='987'),
#  TaggedDocument(words=['무', '이자', '삼성', '노트북', '북', '5', 'NT', '550', 'EBE', '-', 'K', '38', 'B', ',', 'W', '(', '복합기', '+', '스피커', ')'], tags='988'),
#  TaggedDocument(words=['무', '이자', '삼성', '노트북', '북', '5', 'NT', '550', 'EBE', '-', 'K', '34', 'W', '(', '복합기', '+', '스피커', ')'], tags='989'),
#  TaggedDocument(words=['일', '시불', '삼성', '노트북', '북', '5', 'NT', '550', 'EBE', '-', 'K', '38', 'B', ',', 'W', '(', '복합기', '+', '스피커', ')'], tags='990'),
#  TaggedDocument(words=['일', '시불', '삼성', '노트북', '북', '5', 'NT', '550', 'EBE', '-', 'K', '34', 'W', '(', '복합기', '+', '스피커', ')'], tags='991'),
#  TaggedDocument(words=['헤스', '티', '지', '린넨', '블랜딩', '티', '블라우스', '10', '종'], tags='992'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'k', '인피니티', '러브', '주얼리', '세트'], tags='993'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'k', '인피니티', '러브', '목걸이', '팔찌', '세트'], tags='994'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'k', '인피니티', '러브', '팔찌'], tags='995'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'k', '인피니티', '러브', '귀걸이'], tags='996'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'k', '인피니티', '러브', '반지'], tags='997'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'k', '인피니티', '러브', '팔찌', '반지', '세트'], tags='998'),
#  TaggedDocument(words=['[', '루이띠', '에', ']', '18', 'k', '인피니티', '러브', '목걸이'], tags='999'),
#  ...]

# %%
doc_vectorizer.build_vocab(tagged_train_docs)
print(str(doc_vectorizer))
# Out:
# Doc2Vec(dbow+w,d50,n5,w8,mc2,s0.001,t8)

# %%
import time
from tqdm import tnrange
start_time = time.time()

for epoch in tnrange(10):
    doc_vectorizer.train(tagged_train_docs, total_examples=doc_vectorizer.corpus_count, epochs=doc_vectorizer.iter)
    doc_vectorizer.alpha -= 0.002 # decrease the learning rate
    doc_vectorizer.min_alpha = doc_vectorizer.alpha # fix the learning rate, no decay

print("start_time", start_time) 
print("--- %s seconds ---" %(time.time() - start_time))
# Out:
# C:\Users\cjswo\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   """
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# C:\Users\cjswo\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# start_time 1598429007.88933
# --- 33.65971779823303 seconds ---

# %%
X = np.array([doc_vectorizer.infer_vector(doc.words) for doc in tagged_train_docs])
y = np.array([int(doc.tags) for doc in tagged_train_docs])

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse

# %%
# product_names_df에 상품명 추가


product_name_list = data['product_name'].tolist()
uniq_product_name = []
for v in product_name_list:
    if v not in uniq_product_name:
        uniq_product_name.append(v)

# %%
# 상품명 개수가 토큰이랑 일치하지않아 8개 row 제거
len(uniq_product_name)
uniq_product_names_df = pd.DataFrame(uniq_product_name, columns=['product_name'])

# %%
uniq_product_names_df.drop([521, 773, 1200, 1435, 1436, 1575, 1576, 1644],inplace = True)

# %%
# 인덱스 재배열
uniq_product_names_df.reset_index(inplace = True)
uniq_product_names_df
# Out:
#       index                      product_name
# 0         0                     테이트 남성 셀린니트3종
# 1         1                     테이트 여성 셀린니트3종
# 2         2                  오모떼 레이스 파운데이션 브라
# 3         3     CERINI by PAT 남성 소프트 기모 릴렉스팬츠
# 4         4                       보코 리버시블 무스탕
# ...     ...                               ...
# 1669   1677                     조방할매 낙곱새 6팩세트
# 1670   1678  파격가 니봇 무선 진공 물걸레 로봇청소기 +뉴헤어드라이어기
# 1671   1679                        램프쿡 자동회전냄비
# 1672   1680               벨라홈 스마트 멀티포트 1+1 세트
# 1673   1681                     코몽트 기모 터틀넥 5종
#
# [1674 rows x 2 columns]

# %%
Doc2vec_df = product_names_df.join(uniq_product_names_df['product_name'])

# %%
Doc2vec_df[-100:]
# Out:
#                                                   token index  \
# 1574  [무, 이자, 엘지, 트롬, 건조기, 16, kg, RH, 16, WN, (, 화이...  1574
# 1575  [무, 이자, 엘지, 트롬, 건조기, 14, kg, RH, 14, WN, (, 화이...  1575
# 1576  [일, 시불, 엘지, 트롬, 건조기, 16, kg, RH, 16, WN, (, 화이...  1576
# 1577                            [크리스티나, 앤코, 피치, 기모, 팬츠]  1577
# 1578                          [파뷔, 에, 스페셜에디션, 프라이팬, 세트]  1578
# 1579  [청정, 수산, 완도, 활, 전복, 中, 사이즈, 17-18, 미, (, 1, kg...  1579
# 1580                    [AAC, 한, 우소, 머리, 곰탕, 양, 곰탕, 세트]  1580
# 1581                               [AAC, 한, 우소, 머리, 곰탕]  1581
# 1582                            [AAC, 한, 우소, 머리, 양, 곰탕]  1582
# 1583     [사운드, 룩, 포터블, 블루투스, LP, 턴테이블, SLT, -, 100, BT]  1583
# 1584                                  [NNF, 남성, 패딩, 점퍼]  1584
# 1585                                  [NNF, 여성, 패딩, 점퍼]  1585
# 1586               [CERINI, by, PAT, 남성, 기모, 릴, 렉스, 팬츠]  1586
# 1587                            [크리스티나, 앤코, 리버시, 블, 패딩]  1587
# 1588               [월드컵, 남성, 방한, 트레킹, 화, +, 패딩슈즈, 2, 종]  1588
# 1589               [월드컵, 여성, 방한, 트레킹, 화, +, 패딩슈즈, 2, 종]  1589
# 1590                            [국내, 산, 손질, 새꼬막, 13, 팩]  1590
# 1591       [파격, 가, 굿, 프렌드, 스트레칭, 안마, 매트, GOOD, -, A, 7]  1591
# 1592                               [하림, 치킨, 스테이크, 4, 봉]  1592
# 1593  [[, 완벽, 더블, ], 오, 모, 떼, 모, 달, 웜, 이, 너, 웨어, 3, ...  1593
# 1594                            [국내, 산, 자숙찰, 골뱅이, 7, 팩]  1594
# 1595                           [코펜하겐, 럭스, 판초, 니트, 4, 종]  1595
# 1596                             [까사, 마루, 접이식, 테이블, 세트]  1596
# 1597          [까사, 마루, 접이식, 테이블, 세트, (, 1, +, 1, 세트, )]  1597
# 1598                                  [까사, 마루, 접이식, 의자]  1598
# 1599                  [까사, 마루, 접이식, 벤치, 의자, (, 2, 인, )]  1599
# 1600               [KF, 94, 엔, 웰스, 황사, 방역, 마스크, 100, 매]  1600
# 1601                                 [am, 마카롱, 보온병, 세트]  1601
# 1602                      [디, 키즈, 성인, 리버시, 블, 재킷, 1, 종]  1602
# 1603                      [디, 키즈, 아동, 리버시, 블, 재킷, 1, 종]  1603
# 1604                                [코몽트, 패딩, 3, 종, 세트]  1604
# 1605                                    [강레오, 의, 탕, 요일]  1605
# 1606                       [루시, 헨느, 레이스, 홀리데이, 란쥬, 패키지]  1606
# 1607             [엘지, 생활, 건강, 샤프란, 아우라, 고, 농축, 섬유, 유연제]  1607
# 1608                [셰프, 웨이, 멀티, 핸즈, IH, 프라이팬, (, 신, )]  1608
# 1609                          [구찌, 씨마, 베이직, 양면, 울, 머플러]  1609
# 1610                [구찌, 인터, 로킹, GG, 탑, 핸들, 체인, 숄더, 라지]  1610
# 1611                [구찌, 마이크로, 씨마, GG, 플랩, 2, 단, 장, 지갑]  1611
# 1612                         [버버리, 홀스, 페리, 페이톤, 크로스, 백]  1612
# 1613                         [버버리, 밀덴홀, 체인, 크로스, 백, 미듐]  1613
# 1614                [구찌, 인터, 로킹, GG, 탑, 핸들, 체인, 숄더, 스몰]  1614
# 1615       [[, K, -, SWISS, ], 19, F, /, W, 남성, 벤치, 코트]  1615
# 1616       [[, K, -, SWISS, ], 19, F, /, W, 여성, 벤치, 코트]  1616
# 1617             [이동수, 골프, 남성, 원더, 플렉스, 본, 딩, 팬츠, 3, 종]  1617
# 1618             [이동수, 골프, 여성, 원더, 플렉스, 본, 딩, 팬츠, 3, 종]  1618
# 1619                             [무, 이자, 밸런스, 파워, 플래티늄]  1619
# 1620                             [일, 시불, 밸런스, 파워, 플래티늄]  1620
# 1621                          [스튜디오, 럭스, 터틀넥, 니트, 3, 종]  1621
# 1622          [일, 시불, 키친, 플라워, 대, 용량, 에어, 프라이어, 5.8, L]  1622
# 1623          [무, 이자, 키친, 플라워, 대, 용량, 에어, 프라이어, 5.8, L]  1623
# 1624                                    [통뼈, 감자탕, 8, 팩]  1624
# 1625                         [USPA, 화이트, 라벨, 디태처블, 롱패딩]  1625
# 1626                     [USPA, 화이트, 라벨, 디태처블, 롱패딩, 크롬]  1626
# 1627                    [크리스티나, 앤코, 기, 모, 밴딩, 팬츠, 3, 종]  1627
# 1628  [[, 통영, 바다, 의, 보물, ], 국내, 산, 냉동, 참굴, 200, g, x...  1628
# 1629                           [국내, 산, 손질, 통오징어, 10, 팩]  1629
# 1630                 [K, -, SWISS, 남성, 약, 기모, 팬츠, 3, 종]  1630
# 1631          [CERINI, by, PAT, 남성, 기, 모집, 업, 니트, 3, 종]  1631
# 1632               [EXR, 19, F, /, W, 여성, 퍼포먼스, 패딩, 점퍼]  1632
# 1633               [EXR, 19, F, /, W, 남성, 퍼포먼스, 패딩, 점퍼]  1633
# 1634                            [젠트웰, 남성, 패딩, 코트, 1, 종]  1634
# 1635                        [AHC, 스킨, 케어, 링, 톤, 커버, 크림]  1635
# 1636                               [고창, 꿀, 고구마, 10, kg]  1636
# 1637                        [컨, 시크, 컬러, 마크, 글, 로우, 립스틱]  1637
# 1638                  [셀렉, 프로, 뚝배기, 전기밥솥, (, 멀티, 쿠커, )]  1638
# 1639                        [코치, 시, 그, 니, 처, 에터, 캐리, 올]  1639
# 1640                          [마이클, 코, 어스, 소피아, 라지, 사첼]  1640
# 1641                  [마이클, 코, 어스, 젯셋, 아이템, 라지, 체인, 숄더]  1641
# 1642                  [코치, 시, 그, 니, 처, 레더, 켈시, 사, 첼, 백]  1642
# 1643                                       [고데, 롤, 플러스]  1643
# 1644  [자이언트, 킹, 랍스터, (, 점보, 1, 미, +, 골든, 2, 미, +, 크래...  1644
# 1645            [오, 모, 떼, 오, 리지, 널, 쉐이핑, 브라, 팬티, 시즌, 2]  1645
# 1646                           [피부, 약방, 더, 오리진, 크림, 세트]  1646
# 1647                    [뱅뱅, 여성, 벨, 로, 아, 기모, 밴, 딩, 팬츠]  1647
# 1648                     [저스트, 마이, 사이즈, 코튼, 슬, 리머, 패키지]  1648
# 1649                           [옥샘쿡, 만능, 가마솥, 3, 종, 세트]  1649
# 1650  [무, 이자, 삼성, 4, 도어, 냉장고, T, 9000, RF, 84, R, 90...  1650
# 1651  [일, 시불, 삼성, 4, 도어, 냉장고, T, 9000, RF, 84, R, 90...  1651
# 1652  [무, 이자, 초특, 가, 삼성, 5, 도어, 냉장고, T, 9000, (, RF,...  1652
# 1653  [일, 시불, 삼성, 5, 도어, 냉장고, T, 9000, (, RF, 84, R,...  1653
# 1654      [로베르, 타, 디, 까, 메리노, 밸런스, 업, 지퍼, 쉐이핑, 란쥬, 패키지]  1654
# 1655                  [푸마, 웜셀, 티셔츠, 형, 브라, 탑, 4, 종, 세트]  1655
# 1656                     [푸마, 웜셀, 런닝형, 브라, 탑, 4, 종, 세트]  1656
# 1657                            [완도, 산, 식탁, 앤김, 120, 봉]  1657
# 1658      [스프리스, 여성, 퍼, 부츠, 세트, (, 부츠, +, 패딩, 슬립, 온, )]  1658
# 1659      [스프리스, 남성, 퍼, 부츠, 세트, (, 부츠, +, 패딩, 슬립, 온, )]  1659
# 1660                                  [스프리스, 아동, 퍼, 부츠]  1660
# 1661      [[, 헤스, 티, 지, ], 레나, 폭스, 퍼, 후드, 덕, 다운, 롱, 코트]  1661
# 1662  [마르, 엘라, 로, 사티, 나파, 휘, 메일, 풀, 스킨, 밍크, 하프, 코트, ...  1662
# 1663                    [오델로, 겨울, 모자, 3, 종, (, 2, 차, )]  1663
# 1664                              [산, 머루, 농원, 머루, 원, 액]  1664
# 1665                                   [무, 이자, 도깨비, 그릴]  1665
# 1666                                   [일, 시불, 도깨비, 그릴]  1666
# 1667   [(, 일, 시불, ), 엘렌, 실라, &, 코즈미, 쑥클렌져, (, 단, 하루, )]  1667
# 1668   [(, 무, 이자, ), 엘렌, 실라, &, 코즈미, 쑥클렌져, (, 단, 하루, )]  1668
# 1669                            [조방, 할매, 낙곱새, 6, 팩, 세트]  1669
# 1670  [파격, 가, 니, 봇, 무선, 진공, 물걸레, 로봇청소기, +, 뉴, 헤어드라이어...  1670
# 1671                                [램프, 쿡, 자동, 회전, 냄비]  1671
# 1672                  [벨라, 홈, 스마트, 멀티, 포트, 1, +, 1, 세트]  1672
# 1673                               [코몽트, 기모, 터틀넥, 5, 종]  1673
#
#                                            product_name
# 1574                      무이자 엘지트롬 건조기 16kg RH16WN(화이트)
# 1575                      무이자 엘지트롬 건조기 14kg RH14WN(화이트)
# 1576                      일시불 엘지트롬 건조기 16kg RH16WN(화이트)
# 1577                                     크리스티나앤코 피치기모팬츠
# 1578                                  파뷔에 스페셜에디션 프라이팬세트
# 1579                     청정수산 완도활전복 中사이즈 17-18미(1kg이상!)
# 1580                                    AAC한우소머리곰탕양곰탕세트
# 1581                                       AAC 한우소머리 곰탕
# 1582                                       AAC 한우소머리양곰탕
# 1583                     사운드룩 포터블 블루투스 LP턴테이블 SLT-100BT
# 1584                                        NNF 남성 패딩점퍼
# 1585                                        NNF 여성 패딩점퍼
# 1586                          CERINI by PAT 남성 기모 릴렉스팬츠
# 1587                                    크리스티나앤코 리버시블 패딩
# 1588                           월드컵 남성 방한 트레킹화 + 패딩슈즈 2종
# 1589                           월드컵 여성 방한 트레킹화 + 패딩슈즈 2종
# 1590                                    국내산 손질 새꼬막  13팩
# 1591                       파격가 굿프렌드  스트레칭 안마 매트 GOOD-A7
# 1592                                       하림 치킨스테이크 4봉
# 1593                        [완벽더블]오모떼 모달 웜 이너웨어 3세트+3세트
# 1594                                      국내산 자숙찰골뱅이 7팩
# 1595                                      코펜하겐럭스 판초니트4종
# 1596                                    까사마루 접이식 테이블 세트
# 1597                             까사마루 접이식 테이블 세트(1+1세트)
# 1598                                        까사마루 접이식 의자
# 1599                                 까사마루 접이식 벤치 의자(2인)
# 1600                               KF94 엔웰스황사방역마스크 100매
# 1601                                        am마카롱 보온병세트
# 1602                                    디키즈 성인 리버시블재킷1종
# 1603                                    디키즈 아동 리버시블재킷1종
# 1604                                        코몽트 패딩 3종세트
# 1605                                           강레오의 탕요일
# 1606                               루시헨느 레이스 홀리데이 란쥬 패키지
# 1607                            엘지생활건강 샤프란아우라 고농축 섬유유연제
# 1608                               셰프웨이 멀티핸즈 IH 프라이팬(신)
# 1609                                 구찌 씨마 베이직 양면 울 머플러
# 1610                            구찌 인터로킹 GG 탑핸들 체인 숄더 라지
# 1611                             구찌 마이크로 씨마 GG플랩 2단 장지갑
# 1612                                  버버리 홀스페리 페이톤 크로스백
# 1613                                 버버리 밀덴홀 체인 크로스백 미듐
# 1614                            구찌 인터로킹 GG 탑핸들 체인 숄더 스몰
# 1615                            [K-SWISS] 19F/W 남성 벤치코트
# 1616                            [K-SWISS] 19F/W 여성 벤치코트
# 1617                            이동수골프 남성 원더 플렉스 본딩팬츠 3종
# 1618                            이동수골프 여성 원더 플렉스 본딩팬츠 3종
# 1619                                     무이자 밸런스파워 플래티늄
# 1620                                     일시불 밸런스파워 플래티늄
# 1621                                     스튜디오럭스 터틀넥니트3종
# 1622                          일시불 키친플라워 대용량 에어프라이어 5.8L
# 1623                          무이자 키친플라워 대용량 에어프라이어 5.8L
# 1624                                          통뼈 감자탕 8팩
# 1625                                USPA 화이트라벨 디태처블 롱패딩
# 1626                             USPA 화이트라벨 디태처블 롱패딩 크롬
# 1627                           블랙모어스 알티지 오메가3 3병 (53주분)
# 1628                                   크리스티나앤코 기모밴딩팬츠3종
# 1629                [통영바다의보물] 국내산 냉동 참굴 200g x (10팩+2팩)
# 1630                                    국내산 손질 통오징어 10팩
# 1631                                K-SWISS 남성 약기모 팬츠3종
# 1632                          CERINI by PAT 남성 기모집업니트3종
# 1633                           EXR 19 F/W 여성 퍼포먼스 패딩 점퍼
# 1634                           EXR 19 F/W 남성 퍼포먼스 패딩 점퍼
# 1635                                       젠트웰 남성패딩코트1종
# 1636                                    AHC 스킨케어링 톤커버크림
# 1637                                   컨시크 컬러마크 글로우 립스틱
# 1638                                셀렉프로 뚝배기 전기밥솥(멀티쿠커)
# 1639                                     코치 시그니처 에터 캐리올
# 1640                                   마이클코어스 소피아 라지 사첼
# 1641                             마이클코어스 젯셋 아이템 라지 체인 숄더
# 1642                                  코치 시그니처 레더 켈시 사첼백
# 1643                                            고데롤 플러스
# 1644                        자이언트킹랍스터  (점보1미+골든 2미+ 크래커)
# 1645                              오모떼 오리지널 쉐이핑 브라팬티 시즌2
# 1646                                     피부약방 더오리진 크림세트
# 1647                                    뱅뱅 여성 벨로아기모밴딩팬츠
# 1648                                저스트마이사이즈 코튼 슬리머 패키지
# 1649                                    옥샘쿡 만능 가마솥 3종세트
# 1650             무이자 삼성 4도어 냉장고 T9000 RF84R9003S8+공기청정기
# 1651             일시불 삼성 4도어 냉장고 T9000 RF84R9003S8+공기청정기
# 1652   무이자 초특가 삼성5도어냉장고 T9000(RF84R9203S8) +시카고커트러리5p세트
# 1653  일시불 삼성5도어냉장고 T9000 (RF84R9203S8) +공기청정기 (AX34R...
# 1654                       로베르타 디 까메리노 밸런스업 지퍼쉐이핑 란쥬패키지
# 1655                                푸마 웜셀 티셔츠형 브라탑 4종세트
# 1656                                 푸마 웜셀 런닝형 브라탑 4종세트
# 1657                                      완도산 식탁앤김 120봉
# 1658                           스프리스 여성 퍼부츠 세트(부츠+패딩슬립온)
# 1659                           스프리스 남성 퍼부츠 세트(부츠+패딩슬립온)
# 1660                                        스프리스 아동 퍼부츠
# 1661                             [헤스티지] 레나 폭스퍼후드 덕다운롱코트
# 1662                     마르엘라로사티 나파 휘메일 풀스킨 밍크하프코트(11월)
# 1663                                   오델로 겨울모자 3종 (2차)
# 1664                                         산머루농원 머루원액
# 1665                                          무이자 도깨비그릴
# 1666                                          일시불 도깨비그릴
# 1667                            (일시불)엘렌실라&코즈미 쑥클렌져(단하루)
# 1668                            (무이자)엘렌실라&코즈미 쑥클렌져(단하루)
# 1669                                      조방할매 낙곱새 6팩세트
# 1670                   파격가 니봇 무선 진공 물걸레 로봇청소기 +뉴헤어드라이어기
# 1671                                         램프쿡 자동회전냄비
# 1672                                벨라홈 스마트 멀티포트 1+1 세트
# 1673                                      코몽트 기모 터틀넥 5종

# %%
Doc2vec_df.iloc[80]['product_name']
# Out:
# '아문센 남성 윈터 하드쉘 세트'

# %%
# Document 유사도
A_sparse = sparse.csr_matrix(X)
similarities = cosine_similarity(A_sparse)

# %% [markdown]
# ## 취급액간 비율

# %%
error = []
true_sale = []
pred_sale = []

# %%
for i in list(np.arange(1,1674,1)):
    
   # print('Product Name : ',Doc2vec_df.iloc[i]['product_name'],'\n')

    most_sim_5 = np.argsort(similarities[i,:])[::-1][1:6]
    #print('Similar Product Name Top5 \n')
    
    #for j in list(most_sim_5):
        #print(Doc2vec_df.iloc[j]['product_name'])
    
    # 선택된 상품
    select_prod = Doc2vec_df.iloc[i]['product_name']
    # 선택된 상품과 가장 유사한 상품
    most_similar = Doc2vec_df.iloc[most_sim_5[0]]['product_name']
    
    # 선택된 상품의 평균 취급액
    pro_salesAMT_mean = data[data['product_name'] == select_prod]['salesAMT'].mean()
    # 선택된 상품과 가장 유사한 상품의 평균 취급액
    sim_salesAMT_mean = data[data['product_name'] == most_similar]['salesAMT'].mean()
    # 두 취급액 비율
    error_rate = np.max([pro_salesAMT_mean,sim_salesAMT_mean])/np.min([pro_salesAMT_mean,sim_salesAMT_mean])
    # 선택된 취급액 리스트
    true_sale.append(pro_salesAMT_mean)
    # 유사한 취급액 리스트
    pred_sale.append(sim_salesAMT_mean)
    
    #print('\n','상품 평균 취급액\n:',pro_salesAMT_mean)
    #print('가장 유사한 상품 평균 취급액\n:',sim_salesAMT_mean)
    #print('취급액 간 비율 : ', error_rate)
    #print('\n','-'*40,'\n')
    error.append(error_rate)

    
print('취급액간 비율 평균값 \n: ',np.mean(error))
print('취급액 비율 분산 \n: ',np.var(error))
print('취급액 비율 최대값 \n: ',np.sort(error)[::-1][:20])
print('MAPE : \n',MAPE(np.array(true_sale),np.array(pred_sale)))
# Out:
# 취급액간 비율 평균값
# :  2.5591447822025093
# 취급액 비율 분산
# :  29.712124475710507
# 취급액 비율 최대값
# :  [169.15977961  75.90452826  75.90452826  40.94650625  25.08169601
#   24.2496773   24.2496773   21.55409739  21.000342    21.000342
#   19.76991572  18.16340402  17.73586146  17.73586146  14.76218324
#   14.76218324  14.19329016  13.54922036  13.4982382   13.4982382 ]
# MAPE :
#  101.13359349848298

# %% [markdown]
# 비슷한 상품명 여러개의 취급액을 이용해서 따로 예측해보기 또는 클러스터링으로 분류하기, 앞으러 넣을 피쳐 정리하기, 시간대 별 평균 취급액,

# %% [markdown]
# ## 선택된 상품명과 유사한 상품명 리스트

# %%
for i in list(np.arange(1,1674,30)):
    
    print('Product Name : ',Doc2vec_df.iloc[i]['product_name'],'\n')

    most_sim_5 = np.argsort(similarities[i,:])[::-1][1:6]
    print('Similar Product Name Top5 \n')
    
    for j in list(most_sim_5):
        print(Doc2vec_df.iloc[j]['product_name'])
    
    # 선택된 상품
    select_prod = Doc2vec_df.iloc[i]['product_name']
    # 선택된 상품과 가장 유사한 상품
    most_similar = Doc2vec_df.iloc[most_sim_5[0]]['product_name']
    
    # 선택된 상품의 평균 취급액
    pro_salesAMT_mean = data[data['product_name'] == select_prod]['salesAMT'].mean()
    # 선택된 상품과 가장 유사한 상품의 평균 취급액
    sim_salesAMT_mean = data[data['product_name'] == most_similar]['salesAMT'].mean()
    # 두 취급액 비율
    error_rate = np.max([pro_salesAMT_mean,sim_salesAMT_mean])/np.min([pro_salesAMT_mean,sim_salesAMT_mean])
    print('\n','상품 평균 취급액\n:',pro_salesAMT_mean)
    print('가장 유사한 상품 평균 취급액\n:',sim_salesAMT_mean)
    print('취급액 간 비율 : ', error_rate)
    print('\n','-'*40,'\n')
    error.append(error_rate)

    
print('평균 취급액 비율 : ',np.mean(error))

# %% [markdown]
# ## Feature 생성

# %%
data.shape
# Out:
# (35379, 29)

# %% [markdown]
# ### 토큰화 되지않는 상품명 제거

# %%
not_token_list = ['시크릿 라메종 볼륨 스프레이 (고데기)',
 '시스마르스 보헤미안 소가죽 샌들+뮬 슬리퍼',
 '알비에로 마르티니 1A클라쎄 지오맵 라이트숄더백',
 '초특가 무이자 삼성 유에이치디 티비UN55RU7150FXKR',
 '초특가 일시불 삼성 유에이치디 티비UN55RU7150FXKR',
 '무이자 엘지트롬 건조기 14kg RH14WN(화이트)',
 '일시불 엘지트롬 건조기 16kg RH16WN(화이트)',
 '자이언트킹랍스터  (점보1미+골든 2미+ 크래커)']

# %%
for name in not_token_list:
    not_token_index = data[data['product_name'] == name].index
    data.drop(not_token_index, inplace = True)

# %%
data.drop(data[data['product_name'] == '영광 生 모시떡 100개!!(동부기피70개+검정깨30개)'].index, inplace = True)

# %%
data.shape

# %% [markdown]
# ### 유사한 상품의 평균 취급액 추출 후 feature 생성

# %%
similar_salesAMT = []
mean_sales = data['salesAMT'].mean()
for name in data['product_name']:
    if not name in Doc2vec_df['product_name'].tolist():
        similar_salesAMT.append(mean_sales)
        continue
    
    # 상품명의 Doc2Vec 인덱스 추출
    uniq_product_index = Doc2vec_df[Doc2vec_df['product_name'] == name].index[0]
    
    # 유사한 상품명 Doc2Vec 인덱스 추출
    sim_index = np.argsort(similarities[uniq_product_index,:])[::-1][1]
    
    # 유사한 상품명 추출
    sim_prod_name = Doc2vec_df.iloc[sim_index]['product_name']
    
    # 유사한 상품의 평균 취급액
    mean_salesAMT = data[data['product_name'] == sim_prod_name]['salesAMT'].mean()
    
    # 평균 취급액 리스트 생성
    similar_salesAMT.append(mean_salesAMT)
    
print(len(similar_salesAMT))
# Out:
# 35379

# %%
data['sim_salesAMT'] = similar_salesAMT

# %%
data_dummy['sim_salesAMT'] = similar_salesAMT

# %%
len(similar_salesAMT)
# Out:
# 35379

# %%
data.shape
# Out:
# (35379, 30)
